# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
DataFrame = pd.read_csv("weather_data.csv")
Data = pd.read_csv("price_demand_data.csv")
DataFrame
# Out:
#            Date  Minimum temperature (°C)  Maximum temperature (°C)  \
# 0     1/01/2021                      15.6                      29.9
# 1     2/01/2021                      18.4                      29.0
# 2     3/01/2021                      17.0                      26.2
# 3     4/01/2021                      16.0                      18.6
# 4     5/01/2021                      15.9                      19.1
# ..          ...                       ...                       ...
# 238  27/08/2021                       4.6                      13.6
# 239  28/08/2021                       5.3                      17.8
# 240  29/08/2021                       9.1                      16.2
# 241  30/08/2021                       6.4                      17.6
# 242  31/08/2021                      11.0                      20.1
#
#      Rainfall (mm)  Evaporation (mm)  Sunshine (hours)  \
# 0              0.0               2.8               9.3
# ...

# %%
DataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Date                               243 non-null    object
#  1   Minimum temperature (°C)           242 non-null    float64
#  2   Maximum temperature (°C)           242 non-null    float64
#  3   Rainfall (mm)                      241 non-null    float64
#  4   Evaporation (mm)                   243 non-null    float64
#  5   Sunshine (hours)                   243 non-null    float64
#  6   Direction of maximum wind gust     240 non-null    object
#  7   Speed of maximum wind gust (km/h)  240 non-null    float64
#  8   Time of maximum wind gust          240 non-null    object
#  9   9am Temperature (°C)               242 non-null    float64
#  10  9am relative humidity (%)          242 non-null    float64
# ...

# %%
# change the Date column into date time type
DataFrame["Date"]= pd.to_datetime(DataFrame["Date"])
DataFrame["Date"]
# Out:
# 0     2021-01-01
# 1     2021-02-01
# 2     2021-03-01
# 3     2021-04-01
# 4     2021-05-01
#          ...
# 238   2021-08-27
# 239   2021-08-28
# 240   2021-08-29
# 241   2021-08-30
# 242   2021-08-31
# Name: Date, Length: 243, dtype: datetime64[ns]

# %%
# /the date type has been changed to date time format 
DataFrame["Date"]=DataFrame["Date"]= pd.to_datetime(DataFrame["Date"])
DataFrame["Date"]
# Out:
# 0     2021-01-01
# 1     2021-02-01
# 2     2021-03-01
# 3     2021-04-01
# 4     2021-05-01
#          ...
# 238   2021-08-27
# 239   2021-08-28
# 240   2021-08-29
# 241   2021-08-30
# 242   2021-08-31
# Name: Date, Length: 243, dtype: datetime64[ns]

# %%
DataFrame
# Out:
#           Date  Minimum temperature (°C)  Maximum temperature (°C)  \
# 0   2021-01-01                      15.6                      29.9
# 1   2021-02-01                      18.4                      29.0
# 2   2021-03-01                      17.0                      26.2
# 3   2021-04-01                      16.0                      18.6
# 4   2021-05-01                      15.9                      19.1
# ..         ...                       ...                       ...
# 238 2021-08-27                       4.6                      13.6
# 239 2021-08-28                       5.3                      17.8
# 240 2021-08-29                       9.1                      16.2
# 241 2021-08-30                       6.4                      17.6
# 242 2021-08-31                      11.0                      20.1
#
#      Rainfall (mm)  Evaporation (mm)  Sunshine (hours)  \
# 0              0.0               2.8               9.3
# ...

# %%
Data
# Out:
#       REGION    SETTLEMENTDATE  TOTALDEMAND PRICECATEGORY
# 0       VIC1    1/01/2021 0:30      4179.21           LOW
# 1       VIC1    1/01/2021 1:00      4047.76           LOW
# 2       VIC1    1/01/2021 1:30      3934.70           LOW
# 3       VIC1    1/01/2021 2:00      3766.45           LOW
# 4       VIC1    1/01/2021 2:30      3590.37           LOW
# ...      ...               ...          ...           ...
# 11659   VIC1  31/08/2021 22:00      4861.91        MEDIUM
# 11660   VIC1  31/08/2021 22:30      4748.74        MEDIUM
# 11661   VIC1  31/08/2021 23:00      4620.09        MEDIUM
# 11662   VIC1  31/08/2021 23:30      4834.00        MEDIUM
# 11663   VIC1    1/09/2021 0:00      4811.27        MEDIUM
#
# [11664 rows x 4 columns]

# %%
# Check the data type in all the column
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11664 entries, 0 to 11663
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   REGION          11664 non-null  object
#  1   SETTLEMENTDATE  11664 non-null  object
#  2   TOTALDEMAND     11664 non-null  float64
#  3   PRICECATEGORY   11664 non-null  object
# dtypes: float64(1), object(3)
# memory usage: 364.6+ KB

# %%
# We need to extract the dates from /date_time data, for that we convert the column type to datetime format instead of object type
Data["SETTLEMENTDATE"]= pd.to_datetime(Data["SETTLEMENTDATE"])
Data["SETTLEMENTDATE"]
# Out:
# 0       2021-01-01 00:30:00
# 1       2021-01-01 01:00:00
# 2       2021-01-01 01:30:00
# 3       2021-01-01 02:00:00
# 4       2021-01-01 02:30:00
#                 ...
# 11659   2021-08-31 22:00:00
# 11660   2021-08-31 22:30:00
# 11661   2021-08-31 23:00:00
# 11662   2021-08-31 23:30:00
# 11663   2021-01-09 00:00:00
# Name: SETTLEMENTDATE, Length: 11664, dtype: datetime64[ns]

# %%
Data["SETTLEMENTDATE"].dt.date
# Out:
# 0        2021-01-01
# 1        2021-01-01
# 2        2021-01-01
# 3        2021-01-01
# 4        2021-01-01
#             ...
# 11659    2021-08-31
# 11660    2021-08-31
# 11661    2021-08-31
# 11662    2021-08-31
# 11663    2021-01-09
# Name: SETTLEMENTDATE, Length: 11664, dtype: object

# %%
Data["SETTLEMENTDATE"] = Data["SETTLEMENTDATE"].dt.date

# %%
Data
# Out:
#                REGION SETTLEMENTDATE TOTALDEMAND PRICECATEGORY
# 0                VIC1     2021-01-01     4179.21           LOW
# 1                VIC1     2021-02-01     4047.76           LOW
# 2                VIC1     2021-03-01      3934.7           LOW
# 3                VIC1     2021-04-01     3766.45           LOW
# 4                VIC1     2021-05-01     3590.37           LOW
# ...               ...            ...         ...           ...
# 11660            VIC1            NaT     4748.74        MEDIUM
# 11661            VIC1            NaT     4620.09        MEDIUM
# 11662            VIC1            NaT        4834        MEDIUM
# 11663            VIC1            NaT     4811.27        MEDIUM
# SETTLEMENTDATE    NaT            NaT         NaT           NaT
#
# [11665 rows x 4 columns]

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11665 entries, 0 to SETTLEMENTDATE
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   REGION          11664 non-null  object
#  1   SETTLEMENTDATE  243 non-null    datetime64[ns]
#  2   TOTALDEMAND     11664 non-null  object
#  3   PRICECATEGORY   11664 non-null  object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 775.7+ KB

# %%
#Now make them as groups and find the median value
Data.groupby("SETTLEMENTDATE").median()
# Out:
#                 TOTALDEMAND
# SETTLEMENTDATE
# 2021-01-01         3766.450
# 2021-01-02         4771.600
# 2021-01-03         4425.740
# 2021-01-04         4660.755
# 2021-01-05         4232.215
# ...                     ...
# 2021-12-04         5145.220
# 2021-12-05         4882.520
# 2021-12-06         4811.000
# 2021-12-07         5490.590
# 2021-12-08         5114.745
#
# [244 rows x 1 columns]

# %%
# merge both tables by date field

# %%
# Now try to find non matching rows by using exact match, then clean the non matching values.

# %%
Data.combine_first(DataFrame).head(245)
# Out:
#      3pm MSL pressure (hPa)  3pm Temperature (°C)  3pm cloud amount (oktas)  \
# 0                    1015.3                  28.1                       5.0
# 1                    1008.5                  28.7                       7.0
# 2                    1005.2                  23.5                       4.0
# 3                    1011.0                  18.2                       8.0
# 4                    1013.3                  18.2                       8.0
# ..                      ...                   ...                       ...
# 240                  1010.4                  12.8                       7.0
# 241                  1013.2                  16.8                       1.0
# 242                  1012.2                  19.4                       6.0
# 243                     NaN                   NaN                       NaN
# 244                     NaN                   NaN                       NaN
#
# ...

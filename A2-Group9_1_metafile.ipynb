# %%
import pandas as pd #...................................................to load and manipulate data
import numpy as np #....................................................to calculation
import seaborn as sns #.................................................to plot the heatmap

from matplotlib import pyplot as plt #..................................to plot graphs
from sklearn import neighbors #.........................................to find the nearest neighbour
from sklearn.model_selection import train_test_split #..................to split the data into training and testing sets
from sklearn.metrics import accuracy_score #............................to check the accuracy score
from sklearn import preprocessing #.....................................
from sklearn.tree import DecisionTreeClassifier #.......................to buid a classification tree
from sklearn.preprocessing import MinMaxScaler #........................
from ipywidgets import interactive #....................................to create interactive charts
from sklearn.metrics import normalized_mutual_info_score #..............to calculate normalised mutual information

# %matplotlib inline

Data_w = pd.read_csv("weather_data.csv")
Data_p = pd.read_csv("price_demand_data.csv")

Data_w
# Out:
#            Date  Minimum temperature (°C)  Maximum temperature (°C)  \
# 0     1/01/2021                      15.6                      29.9
# 1     2/01/2021                      18.4                      29.0
# 2     3/01/2021                      17.0                      26.2
# 3     4/01/2021                      16.0                      18.6
# 4     5/01/2021                      15.9                      19.1
# ..          ...                       ...                       ...
# 213  24/08/2021                       6.4                      13.1
# 214  25/08/2021                       8.0                      14.1
# 215  28/08/2021                       5.3                      17.8
# 216  29/08/2021                       9.1                      16.2
# 217  30/08/2021                       6.4                      17.6
#
#      Rainfall (mm)  Evaporation (mm)  Sunshine (hours)  \
# 0              0.0               2.8               9.3
# 1              0.0               9.4               1.3
# 2             12.6               4.8               7.1
# 3              2.6               3.8               0.0
# 4             11.2               1.0               0.0
# ..             ...               ...               ...
# 213           10.4               4.0               6.2
# 214            2.2               1.2               5.4
# 215            0.0               1.6               9.6
# 216            0.6               6.4               4.3
# 217            4.0               1.4               7.4
#
#     Direction of maximum wind gust   Speed of maximum wind gust (km/h)  \
# 0                                NE                                 31
# 1                                NW                                 30
# 2                                SW                                 33
# 3                                SE                                 41
# 4                                SE                                 35
# ..                              ...                                ...
# 213                               S                                 39
# 214                               S                                 37
# 215                               N                                 39
# 216                              NE                                 33
# 217                              NW                                 50
#
#     Time of maximum wind gust  9am Temperature (°C)  ...  \
# 0                       13:14                  19.2  ...
# 1                        8:22                  23.3  ...
# 2                       17:55                  18.3  ...
# 3                       16:03                  16.2  ...
# 4                       11:02                  17.2  ...
# ..                        ...                   ...  ...
# 213                      9:38                  10.8  ...
# 214                     16:26                  12.1  ...
# 215                     13:14                   9.1  ...
# 216                      1:50                  10.6  ...
# 217                     14:04                  11.1  ...
#
#      9am cloud amount (oktas)  9am wind direction 9am wind speed (km/h)  \
# 0                           6                   N                     2
# 1                           7                  NW                    17
# 2                           8                  SW                     4
# 3                           8                  SE                    11
# 4                           8                  SE                    13
# ..                        ...                 ...                   ...
# 213                         7                  SE                    17
# 214                         3                  SE                    15
# 215                         1                   N                     7
# 216                         7                   N                    13
# 217                         7                   N                    15
#
#      9am MSL pressure (hPa)  3pm Temperature (°C)  3pm relative humidity (%)  \
# 0                    1018.8                  28.1                         43
# 1                    1013.3                  28.7                         38
# 2                    1007.7                  23.5                         59
# 3                    1010.0                  18.2                         82
# 4                    1012.5                  18.2                         82
# ..                      ...                   ...                        ...
# 213                  1021.5                  11.7                         55
# 214                  1023.3                  13.4                         59
# 215                  1018.6                  17.4                         31
# 216                  1011.4                  12.8                         84
# 217                  1016.1                  16.8                         45
#
#      3pm cloud amount (oktas)  3pm wind direction 3pm wind speed (km/h)  \
# 0                           5                   E                    13
# 1                           7                  SW                     4
# 2                           4                  SW                     2
# 3                           8                  SW                    17
# 4                           8                  SE                    19
# ..                        ...                 ...                   ...
# 213                         6                   S                    17
# 214                         6                  SW                    17
# 215                         3                  NW                    24
# 216                         7                   S                     6
# 217                         1                  NW                    28
#
#      3pm MSL pressure (hPa)
# 0                    1015.3
# 1                    1008.5
# 2                    1005.2
# 3                    1011.0
# 4                    1013.3
# ..                      ...
# 213                  1021.6
# 214                  1021.8
# 215                  1013.5
# 216                  1010.4
# 217                  1013.2
#
# [218 rows x 21 columns]

# %%
 #check the data types 
Data_w.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 218 entries, 0 to 217
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Date                               218 non-null    object
#  1   Minimum temperature (°C)           218 non-null    float64
#  2   Maximum temperature (°C)           218 non-null    float64
#  3   Rainfall (mm)                      218 non-null    float64
#  4   Evaporation (mm)                   218 non-null    float64
#  5   Sunshine (hours)                   218 non-null    float64
#  6   Direction of maximum wind gust     218 non-null    object
#  7   Speed of maximum wind gust (km/h)  218 non-null    int64
#  8   Time of maximum wind gust          218 non-null    object
#  9   9am Temperature (°C)               218 non-null    float64
#  10  9am relative humidity (%)          218 non-null    int64
#  11  9am cloud amount (oktas)           218 non-null    int64
#  12  9am wind direction                 218 non-null    object
#  13  9am wind speed (km/h)              218 non-null    int64
#  14  9am MSL pressure (hPa)             218 non-null    float64
#  15  3pm Temperature (°C)               218 non-null    float64
#  16  3pm relative humidity (%)          218 non-null    int64
#  17  3pm cloud amount (oktas)           218 non-null    int64
#  18  3pm wind direction                 218 non-null    object
#  19  3pm wind speed (km/h)              218 non-null    int64
#  20  3pm MSL pressure (hPa)             218 non-null    float64
# dtypes: float64(9), int64(7), object(5)
# memory usage: 35.9+ KB

# %%
# change the Date column into date time format
Data_w["Date"] = pd.to_datetime(Data_w["Date"])
Data_w["Date"]
# Out:
# 0     2021-01-01
# 1     2021-02-01
# 2     2021-03-01
# 3     2021-04-01
# 4     2021-05-01
#          ...
# 213   2021-08-24
# 214   2021-08-25
# 215   2021-08-28
# 216   2021-08-29
# 217   2021-08-30
# Name: Date, Length: 218, dtype: datetime64[ns]

# %%
# the date type has been changed to date time format, assign to original 
Data_w["Date"] = Data_w["Date"] = pd.to_datetime(Data_w["Date"])
Data_w["Date"]
# Out:
# 0     2021-01-01
# 1     2021-02-01
# 2     2021-03-01
# 3     2021-04-01
# 4     2021-05-01
#          ...
# 213   2021-08-24
# 214   2021-08-25
# 215   2021-08-28
# 216   2021-08-29
# 217   2021-08-30
# Name: Date, Length: 218, dtype: datetime64[ns]

# %%
# Load DataFrame table
Data_w
# Out:
#           Date  Minimum temperature (°C)  Maximum temperature (°C)  \
# 0   2021-01-01                      15.6                      29.9
# 1   2021-02-01                      18.4                      29.0
# 2   2021-03-01                      17.0                      26.2
# 3   2021-04-01                      16.0                      18.6
# 4   2021-05-01                      15.9                      19.1
# ..         ...                       ...                       ...
# 213 2021-08-24                       6.4                      13.1
# 214 2021-08-25                       8.0                      14.1
# 215 2021-08-28                       5.3                      17.8
# 216 2021-08-29                       9.1                      16.2
# 217 2021-08-30                       6.4                      17.6
#
#      Rainfall (mm)  Evaporation (mm)  Sunshine (hours)  \
# 0              0.0               2.8               9.3
# 1              0.0               9.4               1.3
# 2             12.6               4.8               7.1
# 3              2.6               3.8               0.0
# 4             11.2               1.0               0.0
# ..             ...               ...               ...
# 213           10.4               4.0               6.2
# 214            2.2               1.2               5.4
# 215            0.0               1.6               9.6
# 216            0.6               6.4               4.3
# 217            4.0               1.4               7.4
#
#     Direction of maximum wind gust   Speed of maximum wind gust (km/h)  \
# 0                                NE                                 31
# 1                                NW                                 30
# 2                                SW                                 33
# 3                                SE                                 41
# 4                                SE                                 35
# ..                              ...                                ...
# 213                               S                                 39
# 214                               S                                 37
# 215                               N                                 39
# 216                              NE                                 33
# 217                              NW                                 50
#
#     Time of maximum wind gust  9am Temperature (°C)  ...  \
# 0                       13:14                  19.2  ...
# 1                        8:22                  23.3  ...
# 2                       17:55                  18.3  ...
# 3                       16:03                  16.2  ...
# 4                       11:02                  17.2  ...
# ..                        ...                   ...  ...
# 213                      9:38                  10.8  ...
# 214                     16:26                  12.1  ...
# 215                     13:14                   9.1  ...
# 216                      1:50                  10.6  ...
# 217                     14:04                  11.1  ...
#
#      9am cloud amount (oktas)  9am wind direction 9am wind speed (km/h)  \
# 0                           6                   N                     2
# 1                           7                  NW                    17
# 2                           8                  SW                     4
# 3                           8                  SE                    11
# 4                           8                  SE                    13
# ..                        ...                 ...                   ...
# 213                         7                  SE                    17
# 214                         3                  SE                    15
# 215                         1                   N                     7
# 216                         7                   N                    13
# 217                         7                   N                    15
#
#      9am MSL pressure (hPa)  3pm Temperature (°C)  3pm relative humidity (%)  \
# 0                    1018.8                  28.1                         43
# 1                    1013.3                  28.7                         38
# 2                    1007.7                  23.5                         59
# 3                    1010.0                  18.2                         82
# 4                    1012.5                  18.2                         82
# ..                      ...                   ...                        ...
# 213                  1021.5                  11.7                         55
# 214                  1023.3                  13.4                         59
# 215                  1018.6                  17.4                         31
# 216                  1011.4                  12.8                         84
# 217                  1016.1                  16.8                         45
#
#      3pm cloud amount (oktas)  3pm wind direction 3pm wind speed (km/h)  \
# 0                           5                   E                    13
# 1                           7                  SW                     4
# 2                           4                  SW                     2
# 3                           8                  SW                    17
# 4                           8                  SE                    19
# ..                        ...                 ...                   ...
# 213                         6                   S                    17
# 214                         6                  SW                    17
# 215                         3                  NW                    24
# 216                         7                   S                     6
# 217                         1                  NW                    28
#
#      3pm MSL pressure (hPa)
# 0                    1015.3
# 1                    1008.5
# 2                    1005.2
# 3                    1011.0
# 4                    1013.3
# ..                      ...
# 213                  1021.6
# 214                  1021.8
# 215                  1013.5
# 216                  1010.4
# 217                  1013.2
#
# [218 rows x 21 columns]

# %%
#Seprating Dates & Time in diffrent coloumn


Data_p['Date'] = pd. to_datetime(Data_p['SETTLEMENTDATE']). dt. date
Data_p['Time'] = pd. to_datetime(Data_p['SETTLEMENTDATE']). dt. time

display(Data_p.head(10))
# Out:
#   REGION  SETTLEMENTDATE  TOTALDEMAND PRICECATEGORY        Date      Time
# 0   VIC1  1/01/2021 0:30      4179.21           LOW  2021-01-01  00:30:00
# 1   VIC1  1/01/2021 1:00      4047.76           LOW  2021-01-01  01:00:00
# 2   VIC1  1/01/2021 1:30      3934.70           LOW  2021-01-01  01:30:00
# 3   VIC1  1/01/2021 2:00      3766.45           LOW  2021-01-01  02:00:00
# 4   VIC1  1/01/2021 2:30      3590.37           LOW  2021-01-01  02:30:00
# 5   VIC1  1/01/2021 3:00      3549.37           LOW  2021-01-01  03:00:00
# 6   VIC1  1/01/2021 3:30      3504.17           LOW  2021-01-01  03:30:00
# 7   VIC1  1/01/2021 4:00      3547.90           LOW  2021-01-01  04:00:00
# 8   VIC1  1/01/2021 4:30      3579.11           LOW  2021-01-01  04:30:00
# 9   VIC1  1/01/2021 5:00      3580.77           LOW  2021-01-01  05:00:00

# %%
# Load Data Table
Data_p
# Out:
#       REGION    SETTLEMENTDATE  TOTALDEMAND PRICECATEGORY        Date  \
# 0       VIC1    1/01/2021 0:30      4179.21           LOW  2021-01-01
# 1       VIC1    1/01/2021 1:00      4047.76           LOW  2021-01-01
# 2       VIC1    1/01/2021 1:30      3934.70           LOW  2021-01-01
# 3       VIC1    1/01/2021 2:00      3766.45           LOW  2021-01-01
# 4       VIC1    1/01/2021 2:30      3590.37           LOW  2021-01-01
# ...      ...               ...          ...           ...         ...
# 11659   VIC1  31/08/2021 22:00      4861.91        MEDIUM  2021-08-31
# 11660   VIC1  31/08/2021 22:30      4748.74        MEDIUM  2021-08-31
# 11661   VIC1  31/08/2021 23:00      4620.09        MEDIUM  2021-08-31
# 11662   VIC1  31/08/2021 23:30      4834.00        MEDIUM  2021-08-31
# 11663   VIC1    1/09/2021 0:00      4811.27        MEDIUM  2021-01-09
#
#            Time
# 0      00:30:00
# 1      01:00:00
# 2      01:30:00
# 3      02:00:00
# 4      02:30:00
# ...         ...
# 11659  22:00:00
# 11660  22:30:00
# 11661  23:00:00
# 11662  23:30:00
# 11663  00:00:00
#
# [11664 rows x 6 columns]

# %%
# Check the data type in all the columns
Data_p.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11664 entries, 0 to 11663
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   REGION          11664 non-null  object
#  1   SETTLEMENTDATE  11664 non-null  object
#  2   TOTALDEMAND     11664 non-null  float64
#  3   PRICECATEGORY   11664 non-null  object
#  4   Date            11664 non-null  object
#  5   Time            11664 non-null  object
# dtypes: float64(1), object(5)
# memory usage: 546.9+ KB

# %%
# We need to extract the dates from date_time data from the settlement date column, for that we convert the column type to datetime format instead of object type
Data_p["Date"] = pd.to_datetime(Data_p["Date"])
Data_p["Date"]
# Out:
# 0       2021-01-01
# 1       2021-01-01
# 2       2021-01-01
# 3       2021-01-01
# 4       2021-01-01
#            ...
# 11659   2021-08-31
# 11660   2021-08-31
# 11661   2021-08-31
# 11662   2021-08-31
# 11663   2021-01-09
# Name: Date, Length: 11664, dtype: datetime64[ns]

# %%
Data_p
# Out:
#       REGION    SETTLEMENTDATE  TOTALDEMAND PRICECATEGORY       Date      Time
# 0       VIC1    1/01/2021 0:30      4179.21           LOW 2021-01-01  00:30:00
# 1       VIC1    1/01/2021 1:00      4047.76           LOW 2021-01-01  01:00:00
# 2       VIC1    1/01/2021 1:30      3934.70           LOW 2021-01-01  01:30:00
# 3       VIC1    1/01/2021 2:00      3766.45           LOW 2021-01-01  02:00:00
# 4       VIC1    1/01/2021 2:30      3590.37           LOW 2021-01-01  02:30:00
# ...      ...               ...          ...           ...        ...       ...
# 11659   VIC1  31/08/2021 22:00      4861.91        MEDIUM 2021-08-31  22:00:00
# 11660   VIC1  31/08/2021 22:30      4748.74        MEDIUM 2021-08-31  22:30:00
# 11661   VIC1  31/08/2021 23:00      4620.09        MEDIUM 2021-08-31  23:00:00
# 11662   VIC1  31/08/2021 23:30      4834.00        MEDIUM 2021-08-31  23:30:00
# 11663   VIC1    1/09/2021 0:00      4811.27        MEDIUM 2021-01-09  00:00:00
#
# [11664 rows x 6 columns]

# %%
# convert the date into datetime format
Data_p["Date"]= pd.to_datetime(Data_p["Date"])
Data_p["Date"]
# Out:
# 0       2021-01-01
# 1       2021-01-01
# 2       2021-01-01
# 3       2021-01-01
# 4       2021-01-01
#            ...
# 11659   2021-08-31
# 11660   2021-08-31
# 11661   2021-08-31
# 11662   2021-08-31
# 11663   2021-01-09
# Name: Date, Length: 11664, dtype: datetime64[ns]

# %%
Data_p
# Out:
#       REGION    SETTLEMENTDATE  TOTALDEMAND PRICECATEGORY       Date      Time
# 0       VIC1    1/01/2021 0:30      4179.21           LOW 2021-01-01  00:30:00
# 1       VIC1    1/01/2021 1:00      4047.76           LOW 2021-01-01  01:00:00
# 2       VIC1    1/01/2021 1:30      3934.70           LOW 2021-01-01  01:30:00
# 3       VIC1    1/01/2021 2:00      3766.45           LOW 2021-01-01  02:00:00
# 4       VIC1    1/01/2021 2:30      3590.37           LOW 2021-01-01  02:30:00
# ...      ...               ...          ...           ...        ...       ...
# 11659   VIC1  31/08/2021 22:00      4861.91        MEDIUM 2021-08-31  22:00:00
# 11660   VIC1  31/08/2021 22:30      4748.74        MEDIUM 2021-08-31  22:30:00
# 11661   VIC1  31/08/2021 23:00      4620.09        MEDIUM 2021-08-31  23:00:00
# 11662   VIC1  31/08/2021 23:30      4834.00        MEDIUM 2021-08-31  23:30:00
# 11663   VIC1    1/09/2021 0:00      4811.27        MEDIUM 2021-01-09  00:00:00
#
# [11664 rows x 6 columns]

# %%
# convert the date into datetime format
Data_p["Date"]= pd.to_datetime(Data_p["Date"])
Data_p["Date"]
# Out:
# 0       2021-01-01
# 1       2021-01-01
# 2       2021-01-01
# 3       2021-01-01
# 4       2021-01-01
#            ...
# 11659   2021-08-31
# 11660   2021-08-31
# 11661   2021-08-31
# 11662   2021-08-31
# 11663   2021-01-09
# Name: Date, Length: 11664, dtype: datetime64[ns]

# %%
# assign to original
Data_p["Date"]=Data_p["Date"]= pd.to_datetime(Data_p["Date"])
Data_p["Date"]
# Out:
# 0       2021-01-01
# 1       2021-01-01
# 2       2021-01-01
# 3       2021-01-01
# 4       2021-01-01
#            ...
# 11659   2021-08-31
# 11660   2021-08-31
# 11661   2021-08-31
# 11662   2021-08-31
# 11663   2021-01-09
# Name: Date, Length: 11664, dtype: datetime64[ns]

# %%
#Now make them as groups and find the median value_DataMining
Data_pg = Data_p.groupby("Date").max("TOTALDEMAND")
Data_pg
# Out:
#             TOTALDEMAND
# Date
# 2021-01-01      5019.64
# 2021-01-02      5228.29
# 2021-01-03      5225.37
# 2021-01-04      5807.02
# 2021-01-05      5261.09
# ...                 ...
# 2021-12-04      6415.58
# 2021-12-05      6406.00
# 2021-12-06      6062.58
# 2021-12-07      7095.00
# 2021-12-08      6537.70
#
# [244 rows x 1 columns]

# %%
Data_p["TOTALDEMAND"].describe()
# Out:
# count    11664.000000
# mean      4925.798454
# std        876.407490
# min       2708.530000
# 25%       4255.500000
# 50%       4803.755000
# 75%       5477.337500
# max       8196.830000
# Name: TOTALDEMAND, dtype: float64

# %%
#The merged dataframe is assigned as MergeData
MergeData = Data_w.merge(Data_pg, how = 'inner', on = 'Date') 
MergeData
# Out:
#           Date  Minimum temperature (°C)  Maximum temperature (°C)  \
# 0   2021-01-01                      15.6                      29.9
# 1   2021-02-01                      18.4                      29.0
# 2   2021-03-01                      17.0                      26.2
# 3   2021-04-01                      16.0                      18.6
# 4   2021-05-01                      15.9                      19.1
# ..         ...                       ...                       ...
# 213 2021-08-24                       6.4                      13.1
# 214 2021-08-25                       8.0                      14.1
# 215 2021-08-28                       5.3                      17.8
# 216 2021-08-29                       9.1                      16.2
# 217 2021-08-30                       6.4                      17.6
#
#      Rainfall (mm)  Evaporation (mm)  Sunshine (hours)  \
# 0              0.0               2.8               9.3
# 1              0.0               9.4               1.3
# 2             12.6               4.8               7.1
# 3              2.6               3.8               0.0
# 4             11.2               1.0               0.0
# ..             ...               ...               ...
# 213           10.4               4.0               6.2
# 214            2.2               1.2               5.4
# 215            0.0               1.6               9.6
# 216            0.6               6.4               4.3
# 217            4.0               1.4               7.4
#
#     Direction of maximum wind gust   Speed of maximum wind gust (km/h)  \
# 0                                NE                                 31
# 1                                NW                                 30
# 2                                SW                                 33
# 3                                SE                                 41
# 4                                SE                                 35
# ..                              ...                                ...
# 213                               S                                 39
# 214                               S                                 37
# 215                               N                                 39
# 216                              NE                                 33
# 217                              NW                                 50
#
#     Time of maximum wind gust  9am Temperature (°C)  ...  9am wind direction  \
# 0                       13:14                  19.2  ...                   N
# 1                        8:22                  23.3  ...                  NW
# 2                       17:55                  18.3  ...                  SW
# 3                       16:03                  16.2  ...                  SE
# 4                       11:02                  17.2  ...                  SE
# ..                        ...                   ...  ...                 ...
# 213                      9:38                  10.8  ...                  SE
# 214                     16:26                  12.1  ...                  SE
# 215                     13:14                   9.1  ...                   N
# 216                      1:50                  10.6  ...                   N
# 217                     14:04                  11.1  ...                   N
#
#      9am wind speed (km/h) 9am MSL pressure (hPa)  3pm Temperature (°C)  \
# 0                        2                 1018.8                  28.1
# 1                       17                 1013.3                  28.7
# 2                        4                 1007.7                  23.5
# 3                       11                 1010.0                  18.2
# 4                       13                 1012.5                  18.2
# ..                     ...                    ...                   ...
# 213                     17                 1021.5                  11.7
# 214                     15                 1023.3                  13.4
# 215                      7                 1018.6                  17.4
# 216                     13                 1011.4                  12.8
# 217                     15                 1016.1                  16.8
#
#      3pm relative humidity (%)  3pm cloud amount (oktas)  3pm wind direction  \
# 0                           43                         5                   E
# 1                           38                         7                  SW
# 2                           59                         4                  SW
# 3                           82                         8                  SW
# 4                           82                         8                  SE
# ..                         ...                       ...                 ...
# 213                         55                         6                   S
# 214                         59                         6                  SW
# 215                         31                         3                  NW
# 216                         84                         7                   S
# 217                         45                         1                  NW
#
#      3pm wind speed (km/h) 3pm MSL pressure (hPa)  TOTALDEMAND
# 0                       13                 1015.3      5019.64
# 1                        4                 1008.5      4964.35
# 2                        2                 1005.2      4503.31
# 3                       17                 1011.0      4764.18
# 4                       19                 1013.3      4800.64
# ..                     ...                    ...          ...
# 213                     17                 1021.6      6717.65
# 214                     17                 1021.8      6736.80
# 215                     24                 1013.5      5716.32
# 216                      6                 1010.4      6227.89
# 217                     28                 1013.2      6072.91
#
# [218 rows x 22 columns]

# %%
# Average daily temperature

temp = MergeData.loc[:, "Minimum temperature (°C)":"Maximum temperature (°C)"]
MergeData['Average_temp_/day(°C)'] = temp.mean(axis = 1)
MergeData
# Out:
#           Date  Minimum temperature (°C)  Maximum temperature (°C)  \
# 0   2021-01-01                      15.6                      29.9
# 1   2021-02-01                      18.4                      29.0
# 2   2021-03-01                      17.0                      26.2
# 3   2021-04-01                      16.0                      18.6
# 4   2021-05-01                      15.9                      19.1
# ..         ...                       ...                       ...
# 213 2021-08-24                       6.4                      13.1
# 214 2021-08-25                       8.0                      14.1
# 215 2021-08-28                       5.3                      17.8
# 216 2021-08-29                       9.1                      16.2
# 217 2021-08-30                       6.4                      17.6
#
#      Rainfall (mm)  Evaporation (mm)  Sunshine (hours)  \
# 0              0.0               2.8               9.3
# 1              0.0               9.4               1.3
# 2             12.6               4.8               7.1
# 3              2.6               3.8               0.0
# 4             11.2               1.0               0.0
# ..             ...               ...               ...
# 213           10.4               4.0               6.2
# 214            2.2               1.2               5.4
# 215            0.0               1.6               9.6
# 216            0.6               6.4               4.3
# 217            4.0               1.4               7.4
#
#     Direction of maximum wind gust   Speed of maximum wind gust (km/h)  \
# 0                                NE                                 31
# 1                                NW                                 30
# 2                                SW                                 33
# 3                                SE                                 41
# 4                                SE                                 35
# ..                              ...                                ...
# 213                               S                                 39
# 214                               S                                 37
# 215                               N                                 39
# 216                              NE                                 33
# 217                              NW                                 50
#
#     Time of maximum wind gust  9am Temperature (°C)  ...  \
# 0                       13:14                  19.2  ...
# 1                        8:22                  23.3  ...
# 2                       17:55                  18.3  ...
# 3                       16:03                  16.2  ...
# 4                       11:02                  17.2  ...
# ..                        ...                   ...  ...
# 213                      9:38                  10.8  ...
# 214                     16:26                  12.1  ...
# 215                     13:14                   9.1  ...
# 216                      1:50                  10.6  ...
# 217                     14:04                  11.1  ...
#
#      9am wind speed (km/h)  9am MSL pressure (hPa) 3pm Temperature (°C)  \
# 0                        2                  1018.8                 28.1
# 1                       17                  1013.3                 28.7
# 2                        4                  1007.7                 23.5
# 3                       11                  1010.0                 18.2
# 4                       13                  1012.5                 18.2
# ..                     ...                     ...                  ...
# 213                     17                  1021.5                 11.7
# 214                     15                  1023.3                 13.4
# 215                      7                  1018.6                 17.4
# 216                     13                  1011.4                 12.8
# 217                     15                  1016.1                 16.8
#
#      3pm relative humidity (%)  3pm cloud amount (oktas)  3pm wind direction  \
# 0                           43                         5                   E
# 1                           38                         7                  SW
# 2                           59                         4                  SW
# 3                           82                         8                  SW
# 4                           82                         8                  SE
# ..                         ...                       ...                 ...
# 213                         55                         6                   S
# 214                         59                         6                  SW
# 215                         31                         3                  NW
# 216                         84                         7                   S
# 217                         45                         1                  NW
#
#      3pm wind speed (km/h)  3pm MSL pressure (hPa) TOTALDEMAND  \
# 0                       13                  1015.3     5019.64
# 1                        4                  1008.5     4964.35
# 2                        2                  1005.2     4503.31
# 3                       17                  1011.0     4764.18
# 4                       19                  1013.3     4800.64
# ..                     ...                     ...         ...
# 213                     17                  1021.6     6717.65
# 214                     17                  1021.8     6736.80
# 215                     24                  1013.5     5716.32
# 216                      6                  1010.4     6227.89
# 217                     28                  1013.2     6072.91
#
#      Average_temp_/day(°C)
# 0                    22.75
# 1                    23.70
# 2                    21.60
# 3                    17.30
# 4                    17.50
# ..                     ...
# 213                   9.75
# 214                  11.05
# 215                  11.55
# 216                  12.65
# 217                  12.00
#
# [218 rows x 23 columns]

# %%
# Renaming TOTALDEMAND to MAXDEMAND
MergeData.rename(columns = {'TOTALDEMAND':'MAXDEMAND'}, inplace = True)
display(MergeData.head())
# Out:
#         Date  Minimum temperature (°C)  Maximum temperature (°C)  \
# 0 2021-01-01                      15.6                      29.9
# 1 2021-02-01                      18.4                      29.0
# 2 2021-03-01                      17.0                      26.2
# 3 2021-04-01                      16.0                      18.6
# 4 2021-05-01                      15.9                      19.1
#
#    Rainfall (mm)  Evaporation (mm)  Sunshine (hours)  \
# 0            0.0               2.8               9.3
# 1            0.0               9.4               1.3
# 2           12.6               4.8               7.1
# 3            2.6               3.8               0.0
# 4           11.2               1.0               0.0
#
#   Direction of maximum wind gust   Speed of maximum wind gust (km/h)  \
# 0                              NE                                 31
# 1                              NW                                 30
# 2                              SW                                 33
# 3                              SE                                 41
# 4                              SE                                 35
#
#   Time of maximum wind gust  9am Temperature (°C)  ...  9am wind speed (km/h)  \
# 0                     13:14                  19.2  ...                      2
# 1                      8:22                  23.3  ...                     17
# 2                     17:55                  18.3  ...                      4
# 3                     16:03                  16.2  ...                     11
# 4                     11:02                  17.2  ...                     13
#
#    9am MSL pressure (hPa) 3pm Temperature (°C)  3pm relative humidity (%)  \
# 0                  1018.8                 28.1                         43
# 1                  1013.3                 28.7                         38
# 2                  1007.7                 23.5                         59
# 3                  1010.0                 18.2                         82
# 4                  1012.5                 18.2                         82
#
#    3pm cloud amount (oktas)  3pm wind direction  3pm wind speed (km/h)  \
# 0                         5                   E                     13
# 1                         7                  SW                      4
# 2                         4                  SW                      2
# 3                         8                  SW                     17
# 4                         8                  SE                     19
#
#    3pm MSL pressure (hPa) MAXDEMAND  Average_temp_/day(°C)
# 0                  1015.3   5019.64                  22.75
# 1                  1008.5   4964.35                  23.70
# 2                  1005.2   4503.31                  21.60
# 3                  1011.0   4764.18                  17.30
# 4                  1013.3   4800.64                  17.50
#
# [5 rows x 23 columns]

# %%
# Compare maxdemand during different session

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12,10))

ax1 = axes[0][0]
summer_start = '2020-12-01'
summer_end =  '2021-02-28'
summer = MergeData.loc[(MergeData['Date'] >= summer_start) & (MergeData['Date'] <= summer_end)]
summer.plot.scatter (x = 'Maximum temperature (°C)', y = 'MAXDEMAND', title="summer", ax = ax1, lw = 1, c = 'r')
print("Pearson r is ",summer['Maximum temperature (°C)'].corr(summer['MAXDEMAND']), "in summer time")


ax2 = axes[0][1]
autumn_start = '2021-3-01'
autumn_end = '2021-5-31'
autumn = MergeData.loc[(MergeData['Date'] >= autumn_start) & (MergeData['Date'] <= autumn_end)]
autumn.plot.scatter (x = 'Average_temp_/day(°C)', y = 'MAXDEMAND',title="autumn", ax = ax2, lw = 1, c = 'b')
print("Pearson r is ",autumn['Average_temp_/day(°C)'].corr(autumn['MAXDEMAND']), "in Autumn time")


ax3 = axes[1][0]
winter_start = '2021-06-01'
winter_end = '2021-08-31'
winter = MergeData.loc[(MergeData['Date'] >= '2021-06-01') & (MergeData['Date'] <= '2021-08-31') ]
winter.plot.scatter (x = 'Minimum temperature (°C)', y = 'MAXDEMAND',title="winter", ax = ax3, lw = 1, c = 'k')
print("Pearson r is ",winter['Minimum temperature (°C)'].corr(winter['MAXDEMAND']), "in winter time")


plt.subplots_adjust(left=0.1,bottom=0.1, right=0.9, top=0.9, wspace=0.4, hspace=0.4)
plt.show()
# Out:
# Pearson r is  0.4512538011046844 in summer time
# Pearson r is  -0.7205974296273788 in Autumn time
# Pearson r is  -0.6945727109976217 in winter time

# %%
#Make a MATRIX1
FEACHERS = (['MAXDEMAND','Minimum temperature (°C)','Maximum temperature (°C)','Rainfall (mm)',
            'Evaporation (mm)','Sunshine (hours)','Speed of maximum wind gust (km/h)',
            'Time of maximum wind gust','9am Temperature (°C)','9am relative humidity (%)'])
MergeData[FEACHERS].corr(method = 'pearson')
# Out:
#                                    MAXDEMAND  Minimum temperature (°C)  \
# MAXDEMAND                           1.000000                 -0.473554
# Minimum temperature (°C)           -0.473554                  1.000000
# Maximum temperature (°C)           -0.255099                  0.701584
# Rainfall (mm)                      -0.102213                  0.058010
# Evaporation (mm)                   -0.245547                  0.650019
# Sunshine (hours)                   -0.168017                  0.117211
# Speed of maximum wind gust (km/h)   0.110848                  0.002160
# 9am Temperature (°C)               -0.359269                  0.910744
# 9am relative humidity (%)           0.097664                 -0.327113
#
#                                    Maximum temperature (°C)  Rainfall (mm)  \
# MAXDEMAND                                         -0.255099      -0.102213
# Minimum temperature (°C)                           0.701584       0.058010
# Maximum temperature (°C)                           1.000000      -0.122528
# Rainfall (mm)                                     -0.122528       1.000000
# Evaporation (mm)                                   0.626420      -0.067168
# Sunshine (hours)                                   0.489657      -0.118420
# Speed of maximum wind gust (km/h)                 -0.088700       0.013371
# 9am Temperature (°C)                               0.818239      -0.018478
# 9am relative humidity (%)                         -0.304566       0.190563
#
#                                    Evaporation (mm)  Sunshine (hours)  \
# MAXDEMAND                                 -0.245547         -0.168017
# Minimum temperature (°C)                   0.650019          0.117211
# Maximum temperature (°C)                   0.626420          0.489657
# Rainfall (mm)                             -0.067168         -0.118420
# Evaporation (mm)                           1.000000          0.306203
# Sunshine (hours)                           0.306203          1.000000
# Speed of maximum wind gust (km/h)          0.115854         -0.034018
# 9am Temperature (°C)                       0.707067          0.224974
# 9am relative humidity (%)                 -0.539895         -0.262985
#
#                                    Speed of maximum wind gust (km/h)  \
# MAXDEMAND                                                   0.110848
# Minimum temperature (°C)                                    0.002160
# Maximum temperature (°C)                                   -0.088700
# Rainfall (mm)                                               0.013371
# Evaporation (mm)                                            0.115854
# Sunshine (hours)                                           -0.034018
# Speed of maximum wind gust (km/h)                           1.000000
# 9am Temperature (°C)                                        0.075885
# 9am relative humidity (%)                                  -0.337354
#
#                                    9am Temperature (°C)  \
# MAXDEMAND                                     -0.359269
# Minimum temperature (°C)                       0.910744
# Maximum temperature (°C)                       0.818239
# Rainfall (mm)                                 -0.018478
# Evaporation (mm)                               0.707067
# Sunshine (hours)                               0.224974
# Speed of maximum wind gust (km/h)              0.075885
# 9am Temperature (°C)                           1.000000
# 9am relative humidity (%)                     -0.478083
#
#                                    9am relative humidity (%)
# MAXDEMAND                                           0.097664
# Minimum temperature (°C)                           -0.327113
# Maximum temperature (°C)                           -0.304566
# Rainfall (mm)                                       0.190563
# Evaporation (mm)                                   -0.539895
# Sunshine (hours)                                   -0.262985
# Speed of maximum wind gust (km/h)                  -0.337354
# 9am Temperature (°C)                               -0.478083
# 9am relative humidity (%)                           1.000000

# %%
# get max. energy usage of each day
new_price_df=MergeData.groupby(['Date'])['MAXDEMAND'].max().reset_index()
new_price_df.rename(columns= {'TOTALDEMAND':'MAXDEMAND'}, inplace=True)
new_price_df.info()
display(new_price_df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 218 entries, 0 to 217
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       218 non-null    datetime64[ns]
#  1   MAXDEMAND  218 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 3.5 KB
#           Date  MAXDEMAND
# 0   2021-01-01    5019.64
# 1   2021-01-02    5228.29
# 2   2021-01-03    5225.37
# 3   2021-01-04    5807.02
# 4   2021-01-05    5261.09
# ..         ...        ...
# 213 2021-12-03    6115.65
# 214 2021-12-04    6415.58
# 215 2021-12-06    6062.58
# 216 2021-12-07    7095.00
# 217 2021-12-08    6537.70
#
# [218 rows x 2 columns]

# %%
sns.pairplot(Data_w, kind = 'reg', plot_kws = {'ci':None, 'color':'xkcd:red', 'scatter_kws': {'color':'gray'}})

# %%
# Corrilarion values- Strong positive corrilations has light colour, negative corrilations has dark colour.
plt.figure(figsize=(16,8))
sns.heatmap(MergeData.corr(), annot = True, annot_kws={"size":12})

plt.title("Corrilation Map to explain the strength of relationship")
#sns.heatmap(MergeData, annot=True, fmt=".lf", linewidth=5, square=True, cmap='Blues_r')
# Out:
# Text(0.5, 1.0, 'Corrilation Map to explain the strength of relationship')

# %%
#Make a MATRIX2
FEACHERS = (['MAXDEMAND','9am cloud amount (oktas)','9am wind speed (km/h)','9am MSL pressure (hPa)',
             '3pm Temperature (°C)','3pm relative humidity (%)','3pm cloud amount (oktas)',
            '3pm wind speed (km/h)','3pm MSL pressure (hPa)'])
MergeData[FEACHERS].corr(method = 'pearson')
# Out:
#                            MAXDEMAND  9am cloud amount (oktas)  \
# MAXDEMAND                   1.000000                 -0.156732
# 9am cloud amount (oktas)   -0.156732                  1.000000
# 9am wind speed (km/h)       0.148167                 -0.056089
# 9am MSL pressure (hPa)      0.044849                 -0.172483
# 3pm Temperature (°C)       -0.282463                 -0.211235
# 3pm relative humidity (%)   0.054049                  0.452825
# 3pm cloud amount (oktas)    0.084189                  0.409234
# 3pm wind speed (km/h)      -0.019650                 -0.030351
# 3pm MSL pressure (hPa)     -0.018023                 -0.100721
#
#                            9am wind speed (km/h)  9am MSL pressure (hPa)  \
# MAXDEMAND                               0.148167                0.044849
# 9am cloud amount (oktas)               -0.056089               -0.172483
# 9am wind speed (km/h)                   1.000000               -0.214598
# 9am MSL pressure (hPa)                 -0.214598                1.000000
# 3pm Temperature (°C)                   -0.112984               -0.025741
# 3pm relative humidity (%)              -0.161492               -0.152818
# 3pm cloud amount (oktas)                0.010879               -0.296555
# 3pm wind speed (km/h)                   0.371188               -0.103746
# 3pm MSL pressure (hPa)                 -0.231067                0.960922
#
#                            3pm Temperature (°C)  3pm relative humidity (%)  \
# MAXDEMAND                             -0.282463                   0.054049
# 9am cloud amount (oktas)              -0.211235                   0.452825
# 9am wind speed (km/h)                 -0.112984                  -0.161492
# 9am MSL pressure (hPa)                -0.025741                  -0.152818
# 3pm Temperature (°C)                   1.000000                  -0.571804
# 3pm relative humidity (%)             -0.571804                   1.000000
# 3pm cloud amount (oktas)              -0.280805                   0.383701
# 3pm wind speed (km/h)                 -0.027133                  -0.179711
# 3pm MSL pressure (hPa)                -0.121473                  -0.044552
#
#                            3pm cloud amount (oktas)  3pm wind speed (km/h)  \
# MAXDEMAND                                  0.084189              -0.019650
# 9am cloud amount (oktas)                   0.409234              -0.030351
# 9am wind speed (km/h)                      0.010879               0.371188
# 9am MSL pressure (hPa)                    -0.296555              -0.103746
# 3pm Temperature (°C)                      -0.280805              -0.027133
# 3pm relative humidity (%)                  0.383701              -0.179711
# 3pm cloud amount (oktas)                   1.000000              -0.112564
# 3pm wind speed (km/h)                     -0.112564               1.000000
# 3pm MSL pressure (hPa)                    -0.237224              -0.184127
#
#                            3pm MSL pressure (hPa)
# MAXDEMAND                               -0.018023
# 9am cloud amount (oktas)                -0.100721
# 9am wind speed (km/h)                   -0.231067
# 9am MSL pressure (hPa)                   0.960922
# 3pm Temperature (°C)                    -0.121473
# 3pm relative humidity (%)               -0.044552
# 3pm cloud amount (oktas)                -0.237224
# 3pm wind speed (km/h)                   -0.184127
# 3pm MSL pressure (hPa)                   1.000000

# %%
#When the weather is extramly low or exreamly high, then the total demand increases, as people use the energy to maintain the temperature.
MergeData.plot.scatter (x = 'Maximum temperature (°C)',
                        y = 'MAXDEMAND')
# Out:
# <AxesSubplot:xlabel='Maximum temperature (°C)', ylabel='MAXDEMAND'>

# %%
MergeData.plot.scatter (x = '3pm Temperature (°C)',
                        y = 'MAXDEMAND')
# Out:
# <AxesSubplot:xlabel='3pm Temperature (°C)', ylabel='MAXDEMAND'>

# %%
# 3 pm is the time that the temperature goes up in summer.Therefore this chart was plotted to give a random idea on energy demand.

# %%
col = MergeData.loc[:, "Minimum temperature (°C)":"Maximum temperature (°C)"]
MergeData['avg_temp'] = col.mean(axis = 1)
MergeData
# Out:
#           Date  Minimum temperature (°C)  Maximum temperature (°C)  \
# 0   2021-01-01                      15.6                      29.9
# 1   2021-02-01                      18.4                      29.0
# 2   2021-03-01                      17.0                      26.2
# 3   2021-04-01                      16.0                      18.6
# 4   2021-05-01                      15.9                      19.1
# ..         ...                       ...                       ...
# 213 2021-08-24                       6.4                      13.1
# 214 2021-08-25                       8.0                      14.1
# 215 2021-08-28                       5.3                      17.8
# 216 2021-08-29                       9.1                      16.2
# 217 2021-08-30                       6.4                      17.6
#
#      Rainfall (mm)  Evaporation (mm)  Sunshine (hours)  \
# 0              0.0               2.8               9.3
# 1              0.0               9.4               1.3
# 2             12.6               4.8               7.1
# 3              2.6               3.8               0.0
# 4             11.2               1.0               0.0
# ..             ...               ...               ...
# 213           10.4               4.0               6.2
# 214            2.2               1.2               5.4
# 215            0.0               1.6               9.6
# 216            0.6               6.4               4.3
# 217            4.0               1.4               7.4
#
#     Direction of maximum wind gust   Speed of maximum wind gust (km/h)  \
# 0                                NE                                 31
# 1                                NW                                 30
# 2                                SW                                 33
# 3                                SE                                 41
# 4                                SE                                 35
# ..                              ...                                ...
# 213                               S                                 39
# 214                               S                                 37
# 215                               N                                 39
# 216                              NE                                 33
# 217                              NW                                 50
#
#     Time of maximum wind gust  9am Temperature (°C)  ...  \
# 0                       13:14                  19.2  ...
# 1                        8:22                  23.3  ...
# 2                       17:55                  18.3  ...
# 3                       16:03                  16.2  ...
# 4                       11:02                  17.2  ...
# ..                        ...                   ...  ...
# 213                      9:38                  10.8  ...
# 214                     16:26                  12.1  ...
# 215                     13:14                   9.1  ...
# 216                      1:50                  10.6  ...
# 217                     14:04                  11.1  ...
#
#      9am MSL pressure (hPa)  3pm Temperature (°C) 3pm relative humidity (%)  \
# 0                    1018.8                  28.1                        43
# 1                    1013.3                  28.7                        38
# 2                    1007.7                  23.5                        59
# 3                    1010.0                  18.2                        82
# 4                    1012.5                  18.2                        82
# ..                      ...                   ...                       ...
# 213                  1021.5                  11.7                        55
# 214                  1023.3                  13.4                        59
# 215                  1018.6                  17.4                        31
# 216                  1011.4                  12.8                        84
# 217                  1016.1                  16.8                        45
#
#      3pm cloud amount (oktas)  3pm wind direction  3pm wind speed (km/h)  \
# 0                           5                   E                     13
# 1                           7                  SW                      4
# 2                           4                  SW                      2
# 3                           8                  SW                     17
# 4                           8                  SE                     19
# ..                        ...                 ...                    ...
# 213                         6                   S                     17
# 214                         6                  SW                     17
# 215                         3                  NW                     24
# 216                         7                   S                      6
# 217                         1                  NW                     28
#
#      3pm MSL pressure (hPa)  MAXDEMAND Average_temp_/day(°C)  avg_temp
# 0                    1015.3    5019.64                 22.75     22.75
# 1                    1008.5    4964.35                 23.70     23.70
# 2                    1005.2    4503.31                 21.60     21.60
# 3                    1011.0    4764.18                 17.30     17.30
# 4                    1013.3    4800.64                 17.50     17.50
# ..                      ...        ...                   ...       ...
# 213                  1021.6    6717.65                  9.75      9.75
# 214                  1021.8    6736.80                 11.05     11.05
# 215                  1013.5    5716.32                 11.55     11.55
# 216                  1010.4    6227.89                 12.65     12.65
# 217                  1013.2    6072.91                 12.00     12.00
#
# [218 rows x 24 columns]

# %%
MergeData.plot.scatter (x = 'Minimum temperature (°C)',
                        y = 'MAXDEMAND')
# Out:
# <AxesSubplot:xlabel='Minimum temperature (°C)', ylabel='MAXDEMAND'>

# %%
MergeData.plot.scatter (x = 'avg_temp',
                        y = 'MAXDEMAND')
# Out:
# <AxesSubplot:xlabel='avg_temp', ylabel='MAXDEMAND'>

# %%
# when the temperature increases, the evaporation increases. So it will gives a linear graph.
MergeData.plot.scatter (x = 'Maximum temperature (°C)',
                        y = 'Evaporation (mm)', title= " Distribution of Evaporation With Increasing Temperature", c = '#07700a', alpha = 0.7)
# Out:
# <AxesSubplot:title={'center':' Distribution of Evaporation With Increasing Temperature'}, xlabel='Maximum temperature (°C)', ylabel='Evaporation (mm)'>

# %%
Linear=['Evaporation (mm)','Maximum temperature (°C)']
MergeData[Linear].corr(method='pearson')
# Out:
#                           Evaporation (mm)  Maximum temperature (°C)
# Evaporation (mm)                   1.00000                   0.62642
# Maximum temperature (°C)           0.62642                   1.00000

# %%
#To add an identity line, we try to get the max
myMax = max(max(MergeData['Maximum temperature (°C)']), max(MergeData['Evaporation (mm)']))
myMax
# Out:
# 39.2

# %%
# get the min

myMin = min(min(MergeData['Evaporation (mm)']), max(MergeData['MAXDEMAND']))
myMin
# Out:
# 0.0

# %%
# explain ??????????????????????
MergeData.plot.scatter (x = 'Evaporation (mm)',
                        y = 'MAXDEMAND',  title= "Total Demand with Evaporation",c = '#07700a', alpha = 0.7)
# Out:
# <AxesSubplot:title={'center':'Total Demand with Evaporation'}, xlabel='Evaporation (mm)', ylabel='MAXDEMAND'>

# %%
Linear=['Evaporation (mm)','MAXDEMAND']
MergeData[Linear].corr(method='pearson')
# Out:
#                   Evaporation (mm)  MAXDEMAND
# Evaporation (mm)          1.000000  -0.245547
# MAXDEMAND                -0.245547   1.000000

# %%
# get the max

myMax = max(max(MergeData['Evaporation (mm)']), max(MergeData['MAXDEMAND']))
myMax
# Out:
# 8196.83

# %%
# get the min

myMin = min(min(MergeData['Evaporation (mm)']), max(MergeData['MAXDEMAND']))
myMin
# Out:
# 0.0

# %%
# Energy consumption may affect by the other factors too

# %%
# 1.  sunshne data can be effective on solar energy.When the sunshine increases, the Total demand decreases. negatie linear graph.
MergeData.plot.scatter (x = 'Sunshine (hours)',
                        y = 'MAXDEMAND',  title= "Impact of Sunshine on Total Demand",c = '#07700a', alpha = 0.7)
# Out:
# <AxesSubplot:title={'center':'Impact of Sunshine on Total Demand'}, xlabel='Sunshine (hours)', ylabel='MAXDEMAND'>

# %%
# get the max

myMax = max(max(MergeData['Sunshine (hours)']), max(MergeData['MAXDEMAND']))
myMax
# Out:
# 8196.83

# %%
# get the min

myMin = min(min(MergeData['Sunshine (hours)']), max(MergeData['MAXDEMAND']))
myMin
# Out:
# 0.0

# %%
#but the sunshine can be affected by the amount of cloud
MergeData.plot.scatter (x = '9am cloud amount (oktas)',
                        y = 'MAXDEMAND',  title= "Impact of Cloud Amount on Total Demand",c = '#07700a', alpha = 0.7)
# Out:
# <AxesSubplot:title={'center':'Impact of Cloud Amount on Total Demand'}, xlabel='9am cloud amount (oktas)', ylabel='MAXDEMAND'>

# %%
# Less sunshine may due to the cloud amount 
MergeData.plot.scatter (x = 'Sunshine (hours)',
                        y = '9am cloud amount (oktas)',  title= "How the Cloud Amount Will Impact On Sunshine",c = '#07700a', alpha = 0.7)
# Out:
# <AxesSubplot:title={'center':'How the Cloud Amount Will Impact On Sunshine'}, xlabel='Sunshine (hours)', ylabel='9am cloud amount (oktas)'>

# %%
# 2.  Speed of maximum wind gust data can be effective on energy.
MergeData.plot.scatter (x = 'Speed of maximum wind gust (km/h)',
                        y = 'MAXDEMAND',  title= "How the Speed of maximum wind gust Will Impact On Total Demand",c = '#07700a', alpha = 0.7)
# Out:
# <AxesSubplot:title={'center':'How the Speed of maximum wind gust Will Impact On Total Demand'}, xlabel='Speed of maximum wind gust (km/h)', ylabel='MAXDEMAND'>

# %%
MergeData.plot.scatter (x = 'Maximum temperature (°C)',
                        y = '3pm relative humidity (%)', title = "Changing Pattern of Relative Humidity with Increasing Temperature",c = '#07700a', alpha = 0.7)
# Out:
# <AxesSubplot:title={'center':'Changing Pattern of Relative Humidity with Increasing Temperature'}, xlabel='Maximum temperature (°C)', ylabel='3pm relative humidity (%)'>

# %%
Linear=['3pm relative humidity (%)','Maximum temperature (°C)']
MergeData[Linear].corr(method='pearson')
# Out:
#                            3pm relative humidity (%)  Maximum temperature (°C)
# 3pm relative humidity (%)                   1.000000                 -0.475883
# Maximum temperature (°C)                   -0.475883                  1.000000

# %%
# get the max

myMax = max(max(MergeData['Maximum temperature (°C)']), max(MergeData['3pm relative humidity (%)']))
myMax
# Out:
# 98

# %%
# get the min

myMin = min(min(MergeData['Maximum temperature (°C)']), max(MergeData['3pm relative humidity (%)']))
myMin
# Out:
# 10.6

# %%
# This has no relationship
MergeData.plot.scatter (x = '3pm relative humidity (%)',
                        y = 'MAXDEMAND', title = "The Impact of Relative Humidity on Total Demand",c = '#07700a', alpha = 0.7)
# Out:
# <AxesSubplot:title={'center':'The Impact of Relative Humidity on Total Demand'}, xlabel='3pm relative humidity (%)', ylabel='MAXDEMAND'>

# %%
[]# get the max

myMax = max(max(MergeData['3pm relative humidity (%)']), max(Data_pg['TOTALDEMAND']))
myMax
# Out:
# 8196.83

# %%
# get the min

myMin = min(min(MergeData['3pm relative humidity (%)']), max(Data_pg['TOTALDEMAND']))
myMin
# Out:
# 21

# %%
##  Evaluation
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

X = MergeData[['Maximum temperature (°C)']]
y = MergeData['MAXDEMAND']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)


# initialise the model
lm = linear_model.LinearRegression()


#model = lm.fit(X_train, y_train)

model = lm.fit(X_train , y_train)

y_test_predictions = lm.predict(X_test)
print('actual MEDV values of the first 5 test data:')
print(y_test[0:5])
print('')
print('predicted MEDV values of the first 5 test data:')
print(y_test_predictions[0:5])
print('')

# coefficients

print('Coefficients: ', end = ' ')
print(lm.coef_)
print('')

# intercept:
print('Intercept: ', end = ' ')
print(lm.intercept_)
print('')

# R^2
r2_test = lm.score(X_test, y_test)
r2_train = lm.score(X_train, y_train)

print('Coefficient of determination (test): {0:.2f}'.format(r2_test))
print('Coefficient of determination (training): {0:.2f}'.format(r2_train))
# Out:
# actual MEDV values of the first 5 test data:
# 100    5937.22
# 215    5716.32
# 139    6484.85
# 178    7556.79
# 15     4473.05
# Name: MAXDEMAND, dtype: float64
#
# predicted MEDV values of the first 5 test data:
# [6130.75451543 6202.19424704 6327.21377737 6365.48506216 6140.96019137]
#
# Coefficients:  [-25.51418986]
#
# Intercept:  6656.346826591327
#
# Coefficient of determination (test): 0.10
# Coefficient of determination (training): 0.03

# %%
summer_start_date = '2020-12-01'
summer_end_date = '2021-02-28'
# Select DataFrame rows between two dates
mask = (MergeData['Date'] >= summer_start_date) & (MergeData['Date'] <= summer_end_date)
df_summer = MergeData.loc[mask]

# %%
plt.scatter(df_summer['Maximum temperature (°C)'], df_summer['MAXDEMAND'])
plt.xlabel("Maximum temperature (°C)")
plt.ylabel("Maximum demand")
plt.title("Summer time")
plt.show()
print("Pearson r is",df_summer['Maximum temperature (°C)'].corr(df_summer['MAXDEMAND']),"in summer time")
# Out:
# Pearson r is 0.4512538011046844 in summer time

# %%
plt.scatter(df_summer['Minimum temperature (°C)'], df_summer['MAXDEMAND'])
plt.xlabel("Minimum temperature (°C)")
plt.ylabel("Maximum demand")
plt.title("Summer time")
plt.show()
print("Pearson r is",df_summer['Minimum temperature (°C)'].corr(df_summer['MAXDEMAND']),"in summer time")
# Out:
# Pearson r is 0.030960995415587958 in summer time

# %%
winter_start_date = '2021-06-01'
winter_end_date = '2021-08-31'
# Select DataFrame rows between two dates
mask = (MergeData['Date'] >= winter_start_date) & (MergeData['Date'] <= winter_end_date)
df_winter = MergeData.loc[mask]
display(df_winter)
# Out:
#           Date  Minimum temperature (°C)  Maximum temperature (°C)  \
# 5   2021-06-01                      13.7                      19.2
# 6   2021-07-01                      14.7                      25.7
# 7   2021-08-01                      12.7                      24.3
# 34  2021-06-02                      16.9                      25.4
# 35  2021-07-02                      14.7                      19.2
# ..         ...                       ...                       ...
# 213 2021-08-24                       6.4                      13.1
# 214 2021-08-25                       8.0                      14.1
# 215 2021-08-28                       5.3                      17.8
# 216 2021-08-29                       9.1                      16.2
# 217 2021-08-30                       6.4                      17.6
#
#      Rainfall (mm)  Evaporation (mm)  Sunshine (hours)  \
# 5              1.2               1.0               3.2
# 6              0.0               3.6              12.1
# 7              0.0               9.8              13.1
# 34             1.6               9.0               9.5
# 35             1.8               5.6               2.0
# ..             ...               ...               ...
# 213           10.4               4.0               6.2
# 214            2.2               1.2               5.4
# 215            0.0               1.6               9.6
# 216            0.6               6.4               4.3
# 217            4.0               1.4               7.4
#
#     Direction of maximum wind gust   Speed of maximum wind gust (km/h)  \
# 5                                 S                                 35
# 6                                SE                                 44
# 7                                SW                                 31
# 34                               NW                                 39
# 35                               SW                                 37
# ..                              ...                                ...
# 213                               S                                 39
# 214                               S                                 37
# 215                               N                                 39
# 216                              NE                                 33
# 217                              NW                                 50
#
#     Time of maximum wind gust  9am Temperature (°C)  ...  \
# 5                       14:56                  15.2  ...
# 6                       13:21                  18.6  ...
# 7                       15:04                  18.6  ...
# 34                      11:44                  18.6  ...
# 35                      11:23                  15.5  ...
# ..                        ...                   ...  ...
# 213                      9:38                  10.8  ...
# 214                     16:26                  12.1  ...
# 215                     13:14                   9.1  ...
# 216                      1:50                  10.6  ...
# 217                     14:04                  11.1  ...
#
#      9am MSL pressure (hPa)  3pm Temperature (°C) 3pm relative humidity (%)  \
# 5                    1020.0                  18.1                        63
# 6                    1023.9                  24.3                        46
# 7                    1024.8                  23.1                        53
# 34                    998.5                  23.7                        45
# 35                   1011.5                  17.4                        69
# ..                      ...                   ...                       ...
# 213                  1021.5                  11.7                        55
# 214                  1023.3                  13.4                        59
# 215                  1018.6                  17.4                        31
# 216                  1011.4                  12.8                        84
# 217                  1016.1                  16.8                        45
#
#      3pm cloud amount (oktas)  3pm wind direction  3pm wind speed (km/h)  \
# 5                           7                  SW                     17
# 6                           4                  SE                     20
# 7                           1                  SW                     11
# 34                          7                  NW                     11
# 35                          7                   S                     17
# ..                        ...                 ...                    ...
# 213                         6                   S                     17
# 214                         6                  SW                     17
# 215                         3                  NW                     24
# 216                         7                   S                      6
# 217                         1                  NW                     28
#
#      3pm MSL pressure (hPa)  MAXDEMAND Average_temp_/day(°C)  avg_temp
# 5                    1020.0    4691.13                 16.45     16.45
# 6                    1022.0    4994.78                 20.20     20.20
# 7                    1022.2    5365.19                 18.50     18.50
# 34                    999.5    4636.36                 21.15     21.15
# 35                   1013.7    4573.98                 16.95     16.95
# ..                      ...        ...                   ...       ...
# 213                  1021.6    6717.65                  9.75      9.75
# 214                  1021.8    6736.80                 11.05     11.05
# 215                  1013.5    5716.32                 11.55     11.55
# 216                  1010.4    6227.89                 12.65     12.65
# 217                  1013.2    6072.91                 12.00     12.00
#
# [70 rows x 24 columns]

# %%
plt.scatter(df_winter['Maximum temperature (°C)'], df_winter['MAXDEMAND'])
plt.xlabel("Maximum temperature (°C)")
plt.ylabel("Maximum demand")
plt.title("Winter time")
plt.show()
print("Pearson r is",df_winter['Maximum temperature (°C)'].corr(df_winter['MAXDEMAND']),"in winter time.")
# Out:
# Pearson r is -0.76279359668787 in winter time.

# %%
plt.scatter(df_winter['Minimum temperature (°C)'], df_winter['MAXDEMAND'])
plt.xlabel("Minimum temperature (°C)")
plt.ylabel("Maximum demand")
plt.title("Winter time")
plt.show()
print("Pearson r is",df_winter['Minimum temperature (°C)'].corr(df_winter['MAXDEMAND']),"in winter time.")
# Out:
# Pearson r is -0.6945727109976217 in winter time.

# %%
autumn_start_date = '2021-3-01'
autumn_end_date = '2021-5-31'
# Select DataFrame rows between two dates
mask = (MergeData['Date'] >= autumn_start_date) & (MergeData['Date'] <= autumn_end_date)
df_autumn = MergeData.loc[mask]
display(df_autumn)
# Out:
#           Date  Minimum temperature (°C)  Maximum temperature (°C)  \
# 2   2021-03-01                      17.0                      26.2
# 3   2021-04-01                      16.0                      18.6
# 4   2021-05-01                      15.9                      19.1
# 31  2021-03-02                      13.7                      25.9
# 32  2021-04-02                      13.5                      30.6
# ..         ...                       ...                       ...
# 165 2021-04-07                       6.5                      13.1
# 166 2021-05-07                       4.6                      13.1
# 192 2021-03-08                       8.7                      14.5
# 193 2021-04-08                       7.8                      14.5
# 194 2021-05-08                       9.8                      15.8
#
#      Rainfall (mm)  Evaporation (mm)  Sunshine (hours)  \
# 2             12.6               4.8               7.1
# 3              2.6               3.8               0.0
# 4             11.2               1.0               0.0
# 31             0.0               5.4              13.1
# 32             0.0               6.6               4.1
# ..             ...               ...               ...
# 165            0.2               1.2               3.5
# 166            0.4               1.6               1.9
# 192            4.8               2.6               4.1
# 193            0.6               1.8               3.4
# 194            0.4               1.6               3.9
#
#     Direction of maximum wind gust   Speed of maximum wind gust (km/h)  \
# 2                                SW                                 33
# 3                                SE                                 41
# 4                                SE                                 35
# 31                               SE                                 33
# 32                               NW                                 43
# ..                              ...                                ...
# 165                              NW                                 46
# 166                              SW                                 22
# 192                              NW                                 35
# 193                              SW                                 31
# 194                              NW                                 31
#
#     Time of maximum wind gust  9am Temperature (°C)  ...  \
# 2                       17:55                  18.3  ...
# 3                       16:03                  16.2  ...
# 4                       11:02                  17.2  ...
# 31                      16:58                  16.5  ...
# 32                      12:58                  17.3  ...
# ..                        ...                   ...  ...
# 165                     14:32                   7.7  ...
# 166                     12:47                   6.8  ...
# 192                     12:23                  10.6  ...
# 193                     12:09                  10.2  ...
# 194                     14:49                  11.8  ...
#
#      9am MSL pressure (hPa)  3pm Temperature (°C) 3pm relative humidity (%)  \
# 2                    1007.7                  23.5                        59
# 3                    1010.0                  18.2                        82
# 4                    1012.5                  18.2                        82
# 31                   1016.5                  24.1                        44
# 32                   1005.5                  29.2                        32
# ..                      ...                   ...                       ...
# 165                  1016.4                  12.2                        67
# 166                  1022.7                  12.7                        66
# 192                  1008.1                  13.3                        53
# 193                  1016.0                  14.3                        67
# 194                  1021.7                  15.2                        63
#
#      3pm cloud amount (oktas)  3pm wind direction  3pm wind speed (km/h)  \
# 2                           4                  SW                      2
# 3                           8                  SW                     17
# 4                           8                  SE                     19
# 31                          2                  SE                      7
# 32                          7                   N                     28
# ..                        ...                 ...                    ...
# 165                         7                  NW                     17
# 166                         7                  SW                      7
# 192                         6                  NW                     15
# 193                         7                   W                      9
# 194                         7                   W                     15
#
#      3pm MSL pressure (hPa)  MAXDEMAND Average_temp_/day(°C)  avg_temp
# 2                    1005.2    4503.31                 21.60     21.60
# 3                    1011.0    4764.18                 17.30     17.30
# 4                    1013.3    4800.64                 17.50     17.50
# 31                   1011.1    5344.15                 19.80     19.80
# 32                   1002.7    6015.71                 22.05     22.05
# ..                      ...        ...                   ...       ...
# 165                  1015.3    6849.08                  9.80      9.80
# 166                  1021.5    7629.77                  8.85      8.85
# 192                  1007.7    7197.61                 11.60     11.60
# 193                  1015.5    6831.32                 11.15     11.15
# 194                  1020.1    6416.19                 12.80     12.80
#
# [72 rows x 24 columns]

# %%
plt.scatter(df_autumn['Maximum temperature (°C)'], df_autumn['MAXDEMAND'])
plt.xlabel("Maximum temperature (°C)")
plt.ylabel("Maximum demand")
plt.title("Autumn time")
plt.show()
print("Pearson r is",df_autumn['Maximum temperature (°C)'].corr(df_autumn['MAXDEMAND']),"in winter time.")
df_autumn
# Out:
# Pearson r is -0.6107187569125607 in winter time.
#           Date  Minimum temperature (°C)  Maximum temperature (°C)  \
# 2   2021-03-01                      17.0                      26.2
# 3   2021-04-01                      16.0                      18.6
# 4   2021-05-01                      15.9                      19.1
# 31  2021-03-02                      13.7                      25.9
# 32  2021-04-02                      13.5                      30.6
# ..         ...                       ...                       ...
# 165 2021-04-07                       6.5                      13.1
# 166 2021-05-07                       4.6                      13.1
# 192 2021-03-08                       8.7                      14.5
# 193 2021-04-08                       7.8                      14.5
# 194 2021-05-08                       9.8                      15.8
#
#      Rainfall (mm)  Evaporation (mm)  Sunshine (hours)  \
# 2             12.6               4.8               7.1
# 3              2.6               3.8               0.0
# 4             11.2               1.0               0.0
# 31             0.0               5.4              13.1
# 32             0.0               6.6               4.1
# ..             ...               ...               ...
# 165            0.2               1.2               3.5
# 166            0.4               1.6               1.9
# 192            4.8               2.6               4.1
# 193            0.6               1.8               3.4
# 194            0.4               1.6               3.9
#
#     Direction of maximum wind gust   Speed of maximum wind gust (km/h)  \
# 2                                SW                                 33
# 3                                SE                                 41
# 4                                SE                                 35
# 31                               SE                                 33
# 32                               NW                                 43
# ..                              ...                                ...
# 165                              NW                                 46
# 166                              SW                                 22
# 192                              NW                                 35
# 193                              SW                                 31
# 194                              NW                                 31
#
#     Time of maximum wind gust  9am Temperature (°C)  ...  \
# 2                       17:55                  18.3  ...
# 3                       16:03                  16.2  ...
# 4                       11:02                  17.2  ...
# 31                      16:58                  16.5  ...
# 32                      12:58                  17.3  ...
# ..                        ...                   ...  ...
# 165                     14:32                   7.7  ...
# 166                     12:47                   6.8  ...
# 192                     12:23                  10.6  ...
# 193                     12:09                  10.2  ...
# 194                     14:49                  11.8  ...
#
#      9am MSL pressure (hPa)  3pm Temperature (°C) 3pm relative humidity (%)  \
# 2                    1007.7                  23.5                        59
# 3                    1010.0                  18.2                        82
# 4                    1012.5                  18.2                        82
# 31                   1016.5                  24.1                        44
# 32                   1005.5                  29.2                        32
# ..                      ...                   ...                       ...
# 165                  1016.4                  12.2                        67
# 166                  1022.7                  12.7                        66
# 192                  1008.1                  13.3                        53
# 193                  1016.0                  14.3                        67
# 194                  1021.7                  15.2                        63
#
#      3pm cloud amount (oktas)  3pm wind direction  3pm wind speed (km/h)  \
# 2                           4                  SW                      2
# 3                           8                  SW                     17
# 4                           8                  SE                     19
# 31                          2                  SE                      7
# 32                          7                   N                     28
# ..                        ...                 ...                    ...
# 165                         7                  NW                     17
# 166                         7                  SW                      7
# 192                         6                  NW                     15
# 193                         7                   W                      9
# 194                         7                   W                     15
#
#      3pm MSL pressure (hPa)  MAXDEMAND Average_temp_/day(°C)  avg_temp
# 2                    1005.2    4503.31                 21.60     21.60
# 3                    1011.0    4764.18                 17.30     17.30
# 4                    1013.3    4800.64                 17.50     17.50
# 31                   1011.1    5344.15                 19.80     19.80
# 32                   1002.7    6015.71                 22.05     22.05
# ..                      ...        ...                   ...       ...
# 165                  1015.3    6849.08                  9.80      9.80
# 166                  1021.5    7629.77                  8.85      8.85
# 192                  1007.7    7197.61                 11.60     11.60
# 193                  1015.5    6831.32                 11.15     11.15
# 194                  1020.1    6416.19                 12.80     12.80
#
# [72 rows x 24 columns]

# %%
plt.scatter(df_autumn['Minimum temperature (°C)'], df_autumn['MAXDEMAND'])
plt.xlabel("Maximum temperature (°C)")
plt.ylabel("Maximum demand")
plt.title("Autumn time")
plt.show()
print("Pearson r is",df_autumn['Maximum temperature (°C)'].corr(df_autumn['MAXDEMAND']),"in autumn time.")
df_autumn
# Out:
# Pearson r is -0.6107187569125607 in autumn time.
#           Date  Minimum temperature (°C)  Maximum temperature (°C)  \
# 2   2021-03-01                      17.0                      26.2
# 3   2021-04-01                      16.0                      18.6
# 4   2021-05-01                      15.9                      19.1
# 31  2021-03-02                      13.7                      25.9
# 32  2021-04-02                      13.5                      30.6
# ..         ...                       ...                       ...
# 165 2021-04-07                       6.5                      13.1
# 166 2021-05-07                       4.6                      13.1
# 192 2021-03-08                       8.7                      14.5
# 193 2021-04-08                       7.8                      14.5
# 194 2021-05-08                       9.8                      15.8
#
#      Rainfall (mm)  Evaporation (mm)  Sunshine (hours)  \
# 2             12.6               4.8               7.1
# 3              2.6               3.8               0.0
# 4             11.2               1.0               0.0
# 31             0.0               5.4              13.1
# 32             0.0               6.6               4.1
# ..             ...               ...               ...
# 165            0.2               1.2               3.5
# 166            0.4               1.6               1.9
# 192            4.8               2.6               4.1
# 193            0.6               1.8               3.4
# 194            0.4               1.6               3.9
#
#     Direction of maximum wind gust   Speed of maximum wind gust (km/h)  \
# 2                                SW                                 33
# 3                                SE                                 41
# 4                                SE                                 35
# 31                               SE                                 33
# 32                               NW                                 43
# ..                              ...                                ...
# 165                              NW                                 46
# 166                              SW                                 22
# 192                              NW                                 35
# 193                              SW                                 31
# 194                              NW                                 31
#
#     Time of maximum wind gust  9am Temperature (°C)  ...  \
# 2                       17:55                  18.3  ...
# 3                       16:03                  16.2  ...
# 4                       11:02                  17.2  ...
# 31                      16:58                  16.5  ...
# 32                      12:58                  17.3  ...
# ..                        ...                   ...  ...
# 165                     14:32                   7.7  ...
# 166                     12:47                   6.8  ...
# 192                     12:23                  10.6  ...
# 193                     12:09                  10.2  ...
# 194                     14:49                  11.8  ...
#
#      9am MSL pressure (hPa)  3pm Temperature (°C) 3pm relative humidity (%)  \
# 2                    1007.7                  23.5                        59
# 3                    1010.0                  18.2                        82
# 4                    1012.5                  18.2                        82
# 31                   1016.5                  24.1                        44
# 32                   1005.5                  29.2                        32
# ..                      ...                   ...                       ...
# 165                  1016.4                  12.2                        67
# 166                  1022.7                  12.7                        66
# 192                  1008.1                  13.3                        53
# 193                  1016.0                  14.3                        67
# 194                  1021.7                  15.2                        63
#
#      3pm cloud amount (oktas)  3pm wind direction  3pm wind speed (km/h)  \
# 2                           4                  SW                      2
# 3                           8                  SW                     17
# 4                           8                  SE                     19
# 31                          2                  SE                      7
# 32                          7                   N                     28
# ..                        ...                 ...                    ...
# 165                         7                  NW                     17
# 166                         7                  SW                      7
# 192                         6                  NW                     15
# 193                         7                   W                      9
# 194                         7                   W                     15
#
#      3pm MSL pressure (hPa)  MAXDEMAND Average_temp_/day(°C)  avg_temp
# 2                    1005.2    4503.31                 21.60     21.60
# 3                    1011.0    4764.18                 17.30     17.30
# 4                    1013.3    4800.64                 17.50     17.50
# 31                   1011.1    5344.15                 19.80     19.80
# 32                   1002.7    6015.71                 22.05     22.05
# ..                      ...        ...                   ...       ...
# 165                  1015.3    6849.08                  9.80      9.80
# 166                  1021.5    7629.77                  8.85      8.85
# 192                  1007.7    7197.61                 11.60     11.60
# 193                  1015.5    6831.32                 11.15     11.15
# 194                  1020.1    6416.19                 12.80     12.80
#
# [72 rows x 24 columns]

# %%
#QUESTION2

# %%
#................................Question 2 explained...............................................................................................

# %%
Data_p
# Out:
#       REGION    SETTLEMENTDATE  TOTALDEMAND PRICECATEGORY       Date      Time
# 0       VIC1    1/01/2021 0:30      4179.21           LOW 2021-01-01  00:30:00
# 1       VIC1    1/01/2021 1:00      4047.76           LOW 2021-01-01  01:00:00
# 2       VIC1    1/01/2021 1:30      3934.70           LOW 2021-01-01  01:30:00
# 3       VIC1    1/01/2021 2:00      3766.45           LOW 2021-01-01  02:00:00
# 4       VIC1    1/01/2021 2:30      3590.37           LOW 2021-01-01  02:30:00
# ...      ...               ...          ...           ...        ...       ...
# 11659   VIC1  31/08/2021 22:00      4861.91        MEDIUM 2021-08-31  22:00:00
# 11660   VIC1  31/08/2021 22:30      4748.74        MEDIUM 2021-08-31  22:30:00
# 11661   VIC1  31/08/2021 23:00      4620.09        MEDIUM 2021-08-31  23:00:00
# 11662   VIC1  31/08/2021 23:30      4834.00        MEDIUM 2021-08-31  23:30:00
# 11663   VIC1    1/09/2021 0:00      4811.27        MEDIUM 2021-01-09  00:00:00
#
# [11664 rows x 6 columns]

# %%
MergeData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 218 entries, 0 to 217
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Date                               218 non-null    datetime64[ns]
#  1   Minimum temperature (°C)           218 non-null    float64
#  2   Maximum temperature (°C)           218 non-null    float64
#  3   Rainfall (mm)                      218 non-null    float64
#  4   Evaporation (mm)                   218 non-null    float64
#  5   Sunshine (hours)                   218 non-null    float64
#  6   Direction of maximum wind gust     218 non-null    object
#  7   Speed of maximum wind gust (km/h)  218 non-null    int64
#  8   Time of maximum wind gust          218 non-null    object
#  9   9am Temperature (°C)               218 non-null    float64
#  10  9am relative humidity (%)          218 non-null    int64
#  11  9am cloud amount (oktas)           218 non-null    int64
#  12  9am wind direction                 218 non-null    object
#  13  9am wind speed (km/h)              218 non-null    int64
#  14  9am MSL pressure (hPa)             218 non-null    float64
#  15  3pm Temperature (°C)               218 non-null    float64
#  16  3pm relative humidity (%)          218 non-null    int64
#  17  3pm cloud amount (oktas)           218 non-null    int64
#  18  3pm wind direction                 218 non-null    object
#  19  3pm wind speed (km/h)              218 non-null    int64
#  20  3pm MSL pressure (hPa)             218 non-null    float64
#  21  MAXDEMAND                          218 non-null    float64
#  22  Average_temp_/day(°C)              218 non-null    float64
#  23  avg_temp                           218 non-null    float64
#  24  bin_rating                         218 non-null    int64
# dtypes: datetime64[ns](1), float64(12), int64(8), object(4)
# memory usage: 44.3+ KB

# %%
from sklearn.metrics.cluster import normalized_mutual_info_score
MergeData['max_temp_binned']=pd.cut(MergeData['Maximum temperature (°C)'], bins=4)
MergeData['demand_binned']=pd.cut(MergeData['MAXDEMAND'], bins=4)
display(MergeData)
nmi=normalized_mutual_info_score(MergeData['demand_binned'],MergeData['max_temp_binned'], average_method='min')
print("NMI : "+ str(nmi))
# Out:
#           Date  Minimum temperature (°C)  Maximum temperature (°C)  \
# 0   2021-01-01                      15.6                      29.9
# 1   2021-02-01                      18.4                      29.0
# 2   2021-03-01                      17.0                      26.2
# 3   2021-04-01                      16.0                      18.6
# 4   2021-05-01                      15.9                      19.1
# ..         ...                       ...                       ...
# 213 2021-08-24                       6.4                      13.1
# 214 2021-08-25                       8.0                      14.1
# 215 2021-08-28                       5.3                      17.8
# 216 2021-08-29                       9.1                      16.2
# 217 2021-08-30                       6.4                      17.6
#
#      Rainfall (mm)  Evaporation (mm)  Sunshine (hours)  \
# 0              0.0               2.8               9.3
# 1              0.0               9.4               1.3
# 2             12.6               4.8               7.1
# 3              2.6               3.8               0.0
# 4             11.2               1.0               0.0
# ..             ...               ...               ...
# 213           10.4               4.0               6.2
# 214            2.2               1.2               5.4
# 215            0.0               1.6               9.6
# 216            0.6               6.4               4.3
# 217            4.0               1.4               7.4
#
#     Direction of maximum wind gust   Speed of maximum wind gust (km/h)  \
# 0                                NE                                 31
# 1                                NW                                 30
# 2                                SW                                 33
# 3                                SE                                 41
# 4                                SE                                 35
# ..                              ...                                ...
# 213                               S                                 39
# 214                               S                                 37
# 215                               N                                 39
# 216                              NE                                 33
# 217                              NW                                 50
#
#     Time of maximum wind gust  9am Temperature (°C)  ...  \
# 0                       13:14                  19.2  ...
# 1                        8:22                  23.3  ...
# 2                       17:55                  18.3  ...
# 3                       16:03                  16.2  ...
# 4                       11:02                  17.2  ...
# ..                        ...                   ...  ...
# 213                      9:38                  10.8  ...
# 214                     16:26                  12.1  ...
# 215                     13:14                   9.1  ...
# 216                      1:50                  10.6  ...
# 217                     14:04                  11.1  ...
#
#      3pm cloud amount (oktas)  3pm wind direction 3pm wind speed (km/h)  \
# 0                           5                   E                    13
# 1                           7                  SW                     4
# 2                           4                  SW                     2
# 3                           8                  SW                    17
# 4                           8                  SE                    19
# ..                        ...                 ...                   ...
# 213                         6                   S                    17
# 214                         6                  SW                    17
# 215                         3                  NW                    24
# 216                         7                   S                     6
# 217                         1                  NW                    28
#
#      3pm MSL pressure (hPa)  MAXDEMAND  Average_temp_/day(°C)  avg_temp  \
# 0                    1015.3    5019.64                  22.75     22.75
# 1                    1008.5    4964.35                  23.70     23.70
# 2                    1005.2    4503.31                  21.60     21.60
# 3                    1011.0    4764.18                  17.30     17.30
# 4                    1013.3    4800.64                  17.50     17.50
# ..                      ...        ...                    ...       ...
# 213                  1021.6    6717.65                   9.75      9.75
# 214                  1021.8    6736.80                  11.05     11.05
# 215                  1013.5    5716.32                  11.55     11.55
# 216                  1010.4    6227.89                  12.65     12.65
# 217                  1013.2    6072.91                  12.00     12.00
#
#      bin_rating  max_temp_binned         demand_binned
# 0             2    (24.9, 32.05]  (4469.326, 5403.995]
# 1             2    (24.9, 32.05]  (4469.326, 5403.995]
# 2             2    (24.9, 32.05]  (4469.326, 5403.995]
# 3             2    (17.75, 24.9]  (4469.326, 5403.995]
# 4             2    (17.75, 24.9]  (4469.326, 5403.995]
# ..          ...              ...                   ...
# 213           3  (10.571, 17.75]   (6334.94, 7265.885]
# 214           3  (10.571, 17.75]   (6334.94, 7265.885]
# 215           3    (17.75, 24.9]   (5403.995, 6334.94]
# 216           3  (10.571, 17.75]   (5403.995, 6334.94]
# 217           3  (10.571, 17.75]   (5403.995, 6334.94]
#
# [218 rows x 27 columns]
# NMI : 0.32508594193182894

# %%
def bin_rating(x):
    """
   Equal length descritisation.
    
        [min, 4080.605), [4080.605, 5452.68), [5452.68, 6824.755 ) [6824.755, max]
        
        min = 2708.53
        max = 8196.83

    
    """
    LOWER = 4080.605

    MID = 5452.68
    
    UPPER = 6824.755

    
    # [min, 4080.605)
    if x < LOWER:        
        return 1
    
    #  [4080.605, 5452.68)
    elif LOWER <= x < MID:
        return 2 
    
    #  [5452.68, 6824.755 ) 
   
    elif MID <= x < UPPER:
        return 3

   #[6824.755, max]
    return 4

# apply the function on the series
MergeData['bin_rating'] = MergeData['MAXDEMAND'].apply(bin_rating)

# also, print out the min/max for this feature
MergeData
# Out:
#           Date  Minimum temperature (°C)  Maximum temperature (°C)  \
# 0   2021-01-01                      15.6                      29.9
# 1   2021-02-01                      18.4                      29.0
# 2   2021-03-01                      17.0                      26.2
# 3   2021-04-01                      16.0                      18.6
# 4   2021-05-01                      15.9                      19.1
# ..         ...                       ...                       ...
# 238 2021-08-27                       4.6                      13.6
# 239 2021-08-28                       5.3                      17.8
# 240 2021-08-29                       9.1                      16.2
# 241 2021-08-30                       6.4                      17.6
# 242 2021-08-31                      11.0                      20.1
#
#      Rainfall (mm)  Evaporation (mm)  Sunshine (hours)  \
# 0              0.0               2.8               9.3
# 1              0.0               9.4               1.3
# 2             12.6               4.8               7.1
# 3              2.6               3.8               0.0
# 4             11.2               1.0               0.0
# ..             ...               ...               ...
# 238            0.0               1.2               3.8
# 239            0.0               1.6               9.6
# 240            0.6               6.4               4.3
# 241            4.0               1.4               7.4
# 242            0.0               5.8               3.6
#
#     Direction of maximum wind gust   Speed of maximum wind gust (km/h)  \
# 0                               NNE                               31.0
# 1                               NNW                               30.0
# 2                               WSW                               33.0
# 3                               SSE                               41.0
# 4                               SSE                               35.0
# ..                              ...                                ...
# 238                             SSW                               15.0
# 239                               N                               39.0
# 240                             NNE                               33.0
# 241                             NNW                               50.0
# 242                               N                               61.0
#
#     Time of maximum wind gust  9am Temperature (°C)  ...  \
# 0                       13:14                  19.2  ...
# 1                        8:22                  23.3  ...
# 2                       17:55                  18.3  ...
# 3                       16:03                  16.2  ...
# 4                       11:02                  17.2  ...
# ..                        ...                   ...  ...
# 238                     12:18                   7.7  ...
# 239                     13:14                   9.1  ...
# 240                      1:50                  10.6  ...
# 241                     14:04                  11.1  ...
# 242                     16:29                  13.5  ...
#
#      9am MSL pressure (hPa)  3pm Temperature (°C) 3pm relative humidity (%)  \
# 0                    1018.8                  28.1                        43
# 1                    1013.3                  28.7                        38
# 2                    1007.7                  23.5                        59
# 3                    1010.0                  18.2                        82
# 4                    1012.5                  18.2                        82
# ..                      ...                   ...                       ...
# 238                  1020.0                  12.8                        65
# 239                  1018.6                  17.4                        31
# 240                  1011.4                  12.8                        84
# 241                  1016.1                  16.8                        45
# 242                     NaN                  19.4                        43
#
#     3pm cloud amount (oktas)  3pm wind direction  3pm wind speed (km/h)  \
# 0                        5.0                   E                     13
# 1                        7.0                  SW                      4
# 2                        4.0                 SSW                      2
# 3                        8.0                 SSW                     17
# 4                        8.0                 SSE                     19
# ..                       ...                 ...                    ...
# 238                      7.0                 SSE                      7
# 239                      3.0                 NNW                     24
# 240                      7.0                   S                      6
# 241                      1.0                 NNW                     28
# 242                      6.0                   N                     30
#
#      3pm MSL pressure (hPa)  MAXDEMAND Average_temp_/day(°C) bin_rating
# 0                    1015.3    5019.64                 22.75          2
# 1                    1008.5    4964.35                 23.70          2
# 2                    1005.2    4503.31                 21.60          2
# 3                    1011.0    4764.18                 17.30          2
# 4                    1013.3    4800.64                 17.50          2
# ..                      ...        ...                   ...        ...
# 238                  1017.4    6769.89                  9.10          3
# 239                  1013.5    5716.32                 11.55          3
# 240                  1010.4    6227.89                 12.65          3
# 241                  1013.2    6072.91                 12.00          3
# 242                  1012.2    5779.56                 15.55          3
#
# [243 rows x 24 columns]

# %%
##load in the data
Data_p=pd.read_csv('price_demand_data.csv')

##get just the features
data=Data_p[['TOTALDEMAND']].astype(float)


##get just the class labels
classlabel=Data_p['PRICECATEGORY']

##randomly select 66% of the instances to be training and the rest to be testing
X_train, X_test, y_train, y_test = train_test_split(data,classlabel, train_size=0.66, test_size=0.34, random_state=42)

#normalise the data to have 0 mean and unit variance using the library functions.  This will help for later
#computation of distances between instances
scaler = preprocessing.StandardScaler().fit(X_train)
X_train=scaler.transform(X_train)
X_test=scaler.transform(X_test)

# %%
knn = neighbors.KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
# We compare our prediction with the actual class label and report the overall accuracy.
y_pred=knn.predict(X_test)
print(accuracy_score(y_test, y_pred))
# Out:
# 0.6737266767523954

# %%
# Draw a graph of decision tree classification accuracy when the size of the training set is varied 
import numpy
ks = range(1,95,5)
accu_list=[]
for k in ks:
    knn = neighbors.KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train) 
    y_pred=knn.predict(X_test)
    accu_list.append(accuracy_score(y_test, y_pred))
    

plt.plot(ks,accu_list)
plt.show()

# %%
# week 10 refer
m = 'MEDV_h = -3.84 + 5.47*RM -0.63*LSTAT'
y_test_h = Data_p.predict(X_test)
y_train_h = Data_p.predict(X_train)

residual_train = [y - yh for y, yh in zip(y_train, y_train_h)]
residual_test = [y - yh for y, yh in zip(y_test, y_test_h)]

plt.scatter(y_test_h, residual_test, color='C0', label = 'R^2 (test):{0:.2f}'.format(r2_test))
plt.scatter(y_train_h, residual_train, color='C4', alpha = 0.1, label = 'R^2 (training):{0:.2f}'.format(r2_train))
plt.plot([min(y_train_h), max(y_train_h)], [0,0], color= 'C2')
plt.legend()
plt.title("Residule plot\n{}".format(m))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-81-0c2dc2c6afca> in <module>
#       1 # week 10 refer
#       2 m = 'MEDV_h = -3.84 + 5.47*RM -0.63*LSTAT'
# ----> 3 y_test_h = Data_p.predict(X_test)
#       4 y_train_h = Data_p.predict(X_train)
#       5
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'predict'

# %%
# Make them into clusters
Data_p.plot.scatter (x = 'PRICECATEGORY',
                    y = 'TOTALDEMAND', title = "The Total Demand with time",c = '#07700a', alpha = 0.7)
# Out:
# <AxesSubplot:title={'center':'The Total Demand with time'}, xlabel='PRICECATEGORY', ylabel='TOTALDEMAND'>

# %%
# Length Descretization
MergeData.MAXDEMAND.hist(bins = 4, figsize = (10,6))
plt.xlabel("MAXDEMAND")
plt.ylabel("Length desctisation")
plt.title('Distribution of rating after binning')


plt.show()

# %%
# Frequency Descretization
             
MergeData.MAXDEMAND.hist(bins = 10, figsize = (10,6))
plt.xlabel("MAXDEMAND")
plt.ylabel("Frequency Desctisation")
plt.title('Distribution of rating after binning')


plt.show()

# %%
Data_pc = pd.get_dummies(Data_p, columns = ['PRICECATEGORY'])
Data_pc
# Out:
#       REGION    SETTLEMENTDATE  TOTALDEMAND  PRICECATEGORY_EXTREME  \
# 0       VIC1    1/01/2021 0:30      4179.21                      0
# 1       VIC1    1/01/2021 1:00      4047.76                      0
# 2       VIC1    1/01/2021 1:30      3934.70                      0
# 3       VIC1    1/01/2021 2:00      3766.45                      0
# 4       VIC1    1/01/2021 2:30      3590.37                      0
# ...      ...               ...          ...                    ...
# 11659   VIC1  31/08/2021 22:00      4861.91                      0
# 11660   VIC1  31/08/2021 22:30      4748.74                      0
# 11661   VIC1  31/08/2021 23:00      4620.09                      0
# 11662   VIC1  31/08/2021 23:30      4834.00                      0
# 11663   VIC1    1/09/2021 0:00      4811.27                      0
#
#        PRICECATEGORY_HIGH  PRICECATEGORY_LOW  PRICECATEGORY_MEDIUM
# 0                       0                  1                     0
# 1                       0                  1                     0
# 2                       0                  1                     0
# 3                       0                  1                     0
# 4                       0                  1                     0
# ...                   ...                ...                   ...
# 11659                   0                  0                     1
# 11660                   0                  0                     1
# 11661                   0                  0                     1
# 11662                   0                  0                     1
# 11663                   0                  0                     1
#
# [11664 rows x 7 columns]

# %%
# Count values of PriceCategory data entries
Data_p['PRICECATEGORY'].value_counts()
# Out:
# LOW        7570
# MEDIUM     3061
# HIGH        777
# EXTREME     256
# Name: PRICECATEGORY, dtype: int64

# %%
Data_p.PRICECATEGORY.unique()
# Out:
# array(['LOW', 'MEDIUM', 'HIGH', 'EXTREME'], dtype=object)

# %%
# explaining the price category in pie chart
P_CATEGORY=["LOW","MEDIUM","HIGH","EXTREME"]
co2=[7570, 3061,777,256]
colors=['y','g','b','r' ]
plt.pie(co2,explode=None,labels=P_CATEGORY,colors=colors)
plt.axis('equal')
# Out:
# (-1.1112762702946841,
#  1.1005369652521277,
#  -1.1087674267121206,
#  1.1069554353271198)

# %%
# calculating the normalised mutual information for the two categorical variables.( small number means weak relationship) 

from sklearn.metrics import normalized_mutual_info_score
normalized_mutual_info_score(Data_p['SETTLEMENTDATE'], Data_p['PRICECATEGORY'])
# Out:
# 0.17463937143618494

# %% [markdown]
# ## Model accuracy test by K-nearest neighbor classifier

# %%
# # load in the dataset and randomly divide it into training and test sets. We also normalise the data.

features = MergeData[['Minimum temperature (°C)','Maximum temperature (°C)','Rainfall (mm)','Evaporation (mm)','Sunshine (hours)','Speed of maximum wind gust (km/h)']].astype(float)
features
# Out:
#      Minimum temperature (°C)  Maximum temperature (°C)  Rainfall (mm)  \
# 0                        15.6                      29.9            0.0
# 1                        18.4                      29.0            0.0
# 2                        17.0                      26.2           12.6
# 3                        16.0                      18.6            2.6
# 4                        15.9                      19.1           11.2
# ..                        ...                       ...            ...
# 213                       6.4                      13.1           10.4
# 214                       8.0                      14.1            2.2
# 215                       5.3                      17.8            0.0
# 216                       9.1                      16.2            0.6
# 217                       6.4                      17.6            4.0
#
#      Evaporation (mm)  Sunshine (hours)  Speed of maximum wind gust (km/h)
# 0                 2.8               9.3                               31.0
# 1                 9.4               1.3                               30.0
# 2                 4.8               7.1                               33.0
# 3                 3.8               0.0                               41.0
# 4                 1.0               0.0                               35.0
# ..                ...               ...                                ...
# 213               4.0               6.2                               39.0
# 214               1.2               5.4                               37.0
# 215               1.6               9.6                               39.0
# 216               6.4               4.3                               33.0
# 217               1.4               7.4                               50.0
#
# [218 rows x 6 columns]

# %%
train_test_split(features,classlabel, train_size=0.66, test_size=0.34, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-5642dc6140fc> in <module>
# ----> 1 train_test_split(features,classlabel, train_size=0.66, test_size=0.34, random_state=42)
#
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py in train_test_split(*arrays, **options)
#    2125         raise TypeError("Invalid parameters passed: %s" % str(options))
#    2126
# -> 2127     arrays = indexable(*arrays)
#    2128
#    2129     n_samples = _num_samples(arrays[0])
#
# /opt/conda/lib/python3.7/site-packages/sklearn/utils/validation.py in indexable(*iterables)
#     290     """
#     291     result = [_make_indexable(X) for X in iterables]
# --> 292     check_consistent_length(*result)
#     293     return result
#     294
#
# /opt/conda/lib/python3.7/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     254     if len(uniques) > 1:
#     255         raise ValueError("Found input variables with inconsistent numbers of"
# --> 256                          " samples: %r" % [int(l) for l in lengths])
#     257
#     258
#
# ValueError: Found input variables with inconsistent numbers of samples: [218, 11664]

# %%
# STEP 0: Preprocessing 

##get just the class labels
classlabel=MergeData['MAXDEMAND']

##randomly select 66% of the instances to be training and the rest to be testing
X_train, X_test, y_train, y_test = train_test_split(features,classlabel, train_size=0.66, test_size=0.34, random_state=42)

#computation of distances between instances
scaler = preprocessing.StandardScaler().fit(X_train)   # MinMaxScaler()
X_train=scaler.transform(X_train)
X_test=scaler.transform(X_test)

# %%
X_train.shape
# Out:
# (143, 6)

# %%
# STEP 1: Instantiation

knn = neighbors.KNeighborsClassifier(n_neighbors=5)

# STEP 2: Fitting data/Training Data

knn.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-33d490db8c52> in <module>
#       5 # STEP 2: Fitting data/Training Data
#       6
# ----> 7 knn.fit(X_train, y_train)
#
# /opt/conda/lib/python3.7/site-packages/sklearn/neighbors/_base.py in fit(self, X, y)
#    1144             self.outputs_2d_ = True
#    1145
# -> 1146         check_classification_targets(y)
#    1147         self.classes_ = []
#    1148         self._y = np.empty(y.shape, dtype=np.int)
#
# /opt/conda/lib/python3.7/site-packages/sklearn/utils/multiclass.py in check_classification_targets(y)
#     170     if y_type not in ['binary', 'multiclass', 'multiclass-multioutput',
#     171                       'multilabel-indicator', 'multilabel-sequences']:
# --> 172         raise ValueError("Unknown label type: %r" % y_type)
#     173
#     174
#
# ValueError: Unknown label type: 'continuous'

# %%
# STEP 3: Prediction /  Test

y_pred=knn.predict(X_test)

# STEP 4: Evaluation (Accuracy, precision recall fl)

print(accuracy_score(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-19d89bbd984f> in <module>
#       1 # STEP 3: Prediction /  Test
#       2
# ----> 3 y_pred=knn.predict(X_test)
#       4
#       5 # STEP 4: Evaluation (Accuracy, precision recall fl)
#
# /opt/conda/lib/python3.7/site-packages/sklearn/neighbors/_classification.py in predict(self, X)
#     173         X = check_array(X, accept_sparse='csr')
#     174
# --> 175         neigh_dist, neigh_ind = self.kneighbors(X)
#     176         classes_ = self.classes_
#     177         _y = self._y
#
# /opt/conda/lib/python3.7/site-packages/sklearn/neighbors/_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     601         if X is not None:
#     602             query_is_train = False
# --> 603             if self.effective_metric_ == 'precomputed':
#     604                 X = _check_precomputed(X)
#     605             else:
#
# AttributeError: 'KNeighborsClassifier' object has no attribute 'effective_metric_'

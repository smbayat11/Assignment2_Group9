# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
weather_df=pd.read_csv("weather_data.csv")

# %%
price_df=pd.read_csv("price_demand_data.csv")

# %%
display(weather_df)
# Out:
#            Date  Minimum temperature (°C)  Maximum temperature (°C)  \
# 0     1/01/2021                      15.6                      29.9
# 1     2/01/2021                      18.4                      29.0
# 2     3/01/2021                      17.0                      26.2
# 3     4/01/2021                      16.0                      18.6
# 4     5/01/2021                      15.9                      19.1
# ..          ...                       ...                       ...
# 238  27/08/2021                       4.6                      13.6
# 239  28/08/2021                       5.3                      17.8
# 240  29/08/2021                       9.1                      16.2
# 241  30/08/2021                       6.4                      17.6
# 242  31/08/2021                      11.0                      20.1
#
#      Rainfall (mm)  Evaporation (mm)  Sunshine (hours)  \
# 0              0.0               2.8               9.3
# 1              0.0               9.4               1.3
# 2             12.6               4.8               7.1
# 3              2.6               3.8               0.0
# 4             11.2               1.0               0.0
# ..             ...               ...               ...
# 238            0.0               1.2               3.8
# 239            0.0               1.6               9.6
# 240            0.6               6.4               4.3
# 241            4.0               1.4               7.4
# 242            0.0               5.8               3.6
#
#     Direction of maximum wind gust   Speed of maximum wind gust (km/h)  \
# 0                               NNE                               31.0
# 1                               NNW                               30.0
# 2                               WSW                               33.0
# 3                               SSE                               41.0
# 4                               SSE                               35.0
# ..                              ...                                ...
# 238                             SSW                               15.0
# 239                               N                               39.0
# 240                             NNE                               33.0
# 241                             NNW                               50.0
# 242                               N                               61.0
#
#     Time of maximum wind gust  9am Temperature (°C)  ...  \
# 0                       13:14                  19.2  ...
# 1                        8:22                  23.3  ...
# 2                       17:55                  18.3  ...
# 3                       16:03                  16.2  ...
# 4                       11:02                  17.2  ...
# ..                        ...                   ...  ...
# 238                     12:18                   7.7  ...
# 239                     13:14                   9.1  ...
# 240                      1:50                  10.6  ...
# 241                     14:04                  11.1  ...
# 242                     16:29                  13.5  ...
#
#      9am cloud amount (oktas)  9am wind direction 9am wind speed (km/h)  \
# 0                           6                   N                     2
# 1                           7                 NNW                    17
# 2                           8                 WSW                     4
# 3                           8                 SSE                    11
# 4                           8                 SSE                    13
# ..                        ...                 ...                   ...
# 238                         7                                      Calm
# 239                         1                   N                     7
# 240                         7                   N                    13
# 241                         7                   N                    15
# 242                         7                   N                    17
#
#     9am MSL pressure (hPa)  3pm Temperature (°C)  3pm relative humidity (%)  \
# 0                   1018.8                  28.1                         43
# 1                   1013.3                  28.7                         38
# 2                   1007.7                  23.5                         59
# 3                   1010.0                  18.2                         82
# 4                   1012.5                  18.2                         82
# ..                     ...                   ...                        ...
# 238                 1020.0                  12.8                         65
# 239                 1018.6                  17.4                         31
# 240                 1011.4                  12.8                         84
# 241                 1016.1                  16.8                         45
# 242                    NaN                  19.4                         43
#
#      3pm cloud amount (oktas)  3pm wind direction 3pm wind speed (km/h)  \
# 0                         5.0                   E                    13
# 1                         7.0                  SW                     4
# 2                         4.0                 SSW                     2
# 3                         8.0                 SSW                    17
# 4                         8.0                 SSE                    19
# ..                        ...                 ...                   ...
# 238                       7.0                 SSE                     7
# 239                       3.0                 NNW                    24
# 240                       7.0                   S                     6
# 241                       1.0                 NNW                    28
# 242                       6.0                   N                    30
#
#     3pm MSL pressure (hPa)
# 0                   1015.3
# 1                   1008.5
# 2                   1005.2
# 3                   1011.0
# 4                   1013.3
# ..                     ...
# 238                 1017.4
# 239                 1013.5
# 240                 1010.4
# 241                 1013.2
# 242                 1012.2
#
# [243 rows x 21 columns]

# %%
# data cleaning - covert the Date with from string to date format
weather_df['Date'] = pd.to_datetime(weather_df['Date'], format='%d/%m/%Y')

# %%
weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Date                               243 non-null    datetime64[ns]
#  1   Minimum temperature (°C)           242 non-null    float64
#  2   Maximum temperature (°C)           242 non-null    float64
#  3   Rainfall (mm)                      241 non-null    float64
#  4   Evaporation (mm)                   243 non-null    float64
#  5   Sunshine (hours)                   243 non-null    float64
#  6   Direction of maximum wind gust     240 non-null    object
#  7   Speed of maximum wind gust (km/h)  240 non-null    float64
#  8   Time of maximum wind gust          240 non-null    object
#  9   9am Temperature (°C)               242 non-null    float64
#  10  9am relative humidity (%)          242 non-null    float64
#  11  9am cloud amount (oktas)           243 non-null    int64
#  12  9am wind direction                 242 non-null    object
#  13  9am wind speed (km/h)              242 non-null    object
#  14  9am MSL pressure (hPa)             241 non-null    float64
#  15  3pm Temperature (°C)               243 non-null    float64
#  16  3pm relative humidity (%)          243 non-null    int64
#  17  3pm cloud amount (oktas)           242 non-null    float64
#  18  3pm wind direction                 243 non-null    object
#  19  3pm wind speed (km/h)              243 non-null    object
#  20  3pm MSL pressure (hPa)             242 non-null    float64
# dtypes: datetime64[ns](1), float64(12), int64(2), object(6)
# memory usage: 40.0+ KB

# %%
 # data cleaning - delete columns contains not a number value
weather_df=weather_df.dropna(subset=['Maximum temperature (°C)'])

# %%
weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 242 entries, 0 to 242
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Date                               242 non-null    datetime64[ns]
#  1   Minimum temperature (°C)           242 non-null    float64
#  2   Maximum temperature (°C)           242 non-null    float64
#  3   Rainfall (mm)                      241 non-null    float64
#  4   Evaporation (mm)                   242 non-null    float64
#  5   Sunshine (hours)                   242 non-null    float64
#  6   Direction of maximum wind gust     240 non-null    object
#  7   Speed of maximum wind gust (km/h)  240 non-null    float64
#  8   Time of maximum wind gust          240 non-null    object
#  9   9am Temperature (°C)               242 non-null    float64
#  10  9am relative humidity (%)          242 non-null    float64
#  11  9am cloud amount (oktas)           242 non-null    int64
#  12  9am wind direction                 242 non-null    object
#  13  9am wind speed (km/h)              242 non-null    object
#  14  9am MSL pressure (hPa)             241 non-null    float64
#  15  3pm Temperature (°C)               242 non-null    float64
#  16  3pm relative humidity (%)          242 non-null    int64
#  17  3pm cloud amount (oktas)           241 non-null    float64
#  18  3pm wind direction                 242 non-null    object
#  19  3pm wind speed (km/h)              242 non-null    object
#  20  3pm MSL pressure (hPa)             241 non-null    float64
# dtypes: datetime64[ns](1), float64(12), int64(2), object(6)
# memory usage: 41.6+ KB

# %%
# data cleanning - split the SETTLEMENTDATE to Date and TIME
price_df[['Date','TIME']]=price_df['SETTLEMENTDATE'].str.split(' ', expand=True)

# %%
price_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11664 entries, 0 to 11663
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   REGION          11664 non-null  object
#  1   SETTLEMENTDATE  11664 non-null  object
#  2   TOTALDEMAND     11664 non-null  float64
#  3   PRICECATEGORY   11664 non-null  object
#  4   Date            11664 non-null  object
#  5   TIME            11664 non-null  object
# dtypes: float64(1), object(5)
# memory usage: 546.9+ KB

# %%
price_df['Date'] = pd.to_datetime(price_df['Date'], format='%d/%m/%Y')

# %%
price_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11664 entries, 0 to 11663
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   REGION          11664 non-null  object
#  1   SETTLEMENTDATE  11664 non-null  object
#  2   TOTALDEMAND     11664 non-null  float64
#  3   PRICECATEGORY   11664 non-null  object
#  4   Date            11664 non-null  datetime64[ns]
#  5   TIME            11664 non-null  object
# dtypes: datetime64[ns](1), float64(1), object(4)
# memory usage: 546.9+ KB

# %%
# get max. energy usage of each day
new_price_df=price_df.groupby(['Date'])['TOTALDEMAND'].max().reset_index()
new_price_df.rename(columns= {'TOTALDEMAND':'MAXDEMAND'}, inplace=True)
new_price_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       244 non-null    datetime64[ns]
#  1   MAXDEMAND  244 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 3.9 KB

# %%
display(new_price_df)
# Out:
#           Date  MAXDEMAND
# 0   2021-01-01    5019.64
# 1   2021-01-02    4964.35
# 2   2021-01-03    4503.31
# 3   2021-01-04    4764.18
# 4   2021-01-05    4800.64
# ..         ...        ...
# 239 2021-08-28    5716.32
# 240 2021-08-29    6227.89
# 241 2021-08-30    6072.91
# 242 2021-08-31    5779.56
# 243 2021-09-01    4811.27
#
# [244 rows x 2 columns]

# %%
new_price_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       244 non-null    datetime64[ns]
#  1   MAXDEMAND  244 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 3.9 KB

# %%
#merge and combine the data sets
df=pd.merge(new_price_df,weather_df,how="inner", on="Date")

# %%
display(df)
# Out:
#           Date  MAXDEMAND  Minimum temperature (°C)  Maximum temperature (°C)  \
# 0   2021-01-01    5019.64                      15.6                      29.9
# 1   2021-01-02    4964.35                      18.4                      29.0
# 2   2021-01-03    4503.31                      17.0                      26.2
# 3   2021-01-04    4764.18                      16.0                      18.6
# 4   2021-01-05    4800.64                      15.9                      19.1
# ..         ...        ...                       ...                       ...
# 237 2021-08-27    6769.89                       4.6                      13.6
# 238 2021-08-28    5716.32                       5.3                      17.8
# 239 2021-08-29    6227.89                       9.1                      16.2
# 240 2021-08-30    6072.91                       6.4                      17.6
# 241 2021-08-31    5779.56                      11.0                      20.1
#
#      Rainfall (mm)  Evaporation (mm)  Sunshine (hours)  \
# 0              0.0               2.8               9.3
# 1              0.0               9.4               1.3
# 2             12.6               4.8               7.1
# 3              2.6               3.8               0.0
# 4             11.2               1.0               0.0
# ..             ...               ...               ...
# 237            0.0               1.2               3.8
# 238            0.0               1.6               9.6
# 239            0.6               6.4               4.3
# 240            4.0               1.4               7.4
# 241            0.0               5.8               3.6
#
#     Direction of maximum wind gust   Speed of maximum wind gust (km/h)  \
# 0                               NNE                               31.0
# 1                               NNW                               30.0
# 2                               WSW                               33.0
# 3                               SSE                               41.0
# 4                               SSE                               35.0
# ..                              ...                                ...
# 237                             SSW                               15.0
# 238                               N                               39.0
# 239                             NNE                               33.0
# 240                             NNW                               50.0
# 241                               N                               61.0
#
#     Time of maximum wind gust  ...  9am cloud amount (oktas)  \
# 0                       13:14  ...                         6
# 1                        8:22  ...                         7
# 2                       17:55  ...                         8
# 3                       16:03  ...                         8
# 4                       11:02  ...                         8
# ..                        ...  ...                       ...
# 237                     12:18  ...                         7
# 238                     13:14  ...                         1
# 239                      1:50  ...                         7
# 240                     14:04  ...                         7
# 241                     16:29  ...                         7
#
#      9am wind direction  9am wind speed (km/h) 9am MSL pressure (hPa)  \
# 0                     N                      2                 1018.8
# 1                   NNW                     17                 1013.3
# 2                   WSW                      4                 1007.7
# 3                   SSE                     11                 1010.0
# 4                   SSE                     13                 1012.5
# ..                  ...                    ...                    ...
# 237                                       Calm                 1020.0
# 238                   N                      7                 1018.6
# 239                   N                     13                 1011.4
# 240                   N                     15                 1016.1
# 241                   N                     17                    NaN
#
#     3pm Temperature (°C)  3pm relative humidity (%)  3pm cloud amount (oktas)  \
# 0                   28.1                         43                       5.0
# 1                   28.7                         38                       7.0
# 2                   23.5                         59                       4.0
# 3                   18.2                         82                       8.0
# 4                   18.2                         82                       8.0
# ..                   ...                        ...                       ...
# 237                 12.8                         65                       7.0
# 238                 17.4                         31                       3.0
# 239                 12.8                         84                       7.0
# 240                 16.8                         45                       1.0
# 241                 19.4                         43                       6.0
#
#      3pm wind direction  3pm wind speed (km/h) 3pm MSL pressure (hPa)
# 0                     E                     13                 1015.3
# 1                    SW                      4                 1008.5
# 2                   SSW                      2                 1005.2
# 3                   SSW                     17                 1011.0
# 4                   SSE                     19                 1013.3
# ..                  ...                    ...                    ...
# 237                 SSE                      7                 1017.4
# 238                 NNW                     24                 1013.5
# 239                   S                      6                 1010.4
# 240                 NNW                     28                 1013.2
# 241                   N                     30                 1012.2
#
# [242 rows x 22 columns]

# %%
plt.scatter(df['Maximum temperature (°C)'], df['MAXDEMAND'])
plt.xlabel("Maximum temperature (°C)")
plt.ylabel("Maximum demand")
plt.show()
print("Pearson r is",df['Maximum temperature (°C)'].corr(df['MAXDEMAND']))
# Out:
# Pearson r is -0.2921912468488674

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 242 entries, 0 to 241
# Data columns (total 22 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Date                               242 non-null    datetime64[ns]
#  1   MAXDEMAND                          242 non-null    float64
#  2   Minimum temperature (°C)           242 non-null    float64
#  3   Maximum temperature (°C)           242 non-null    float64
#  4   Rainfall (mm)                      241 non-null    float64
#  5   Evaporation (mm)                   242 non-null    float64
#  6   Sunshine (hours)                   242 non-null    float64
#  7   Direction of maximum wind gust     240 non-null    object
#  8   Speed of maximum wind gust (km/h)  240 non-null    float64
#  9   Time of maximum wind gust          240 non-null    object
#  10  9am Temperature (°C)               242 non-null    float64
#  11  9am relative humidity (%)          242 non-null    float64
#  12  9am cloud amount (oktas)           242 non-null    int64
#  13  9am wind direction                 242 non-null    object
#  14  9am wind speed (km/h)              242 non-null    object
#  15  9am MSL pressure (hPa)             241 non-null    float64
#  16  3pm Temperature (°C)               242 non-null    float64
#  17  3pm relative humidity (%)          242 non-null    int64
#  18  3pm cloud amount (oktas)           241 non-null    float64
#  19  3pm wind direction                 242 non-null    object
#  20  3pm wind speed (km/h)              242 non-null    object
#  21  3pm MSL pressure (hPa)             241 non-null    float64
# dtypes: datetime64[ns](1), float64(13), int64(2), object(6)
# memory usage: 43.5+ KB

# %%
from sklearn.metrics.cluster import normalized_mutual_info_score
df['max_temp_binned']=pd.cut(df['Maximum temperature (°C)'], bins=4)
df['demand_binned']=pd.cut(df['MAXDEMAND'], bins=4)
display(df)
nmi=normalized_mutual_info_score(df['demand_binned'],df['max_temp_binned'], average_method='min')
print("NMI : "+ str(nmi))
# Out:
#           Date  MAXDEMAND  Minimum temperature (°C)  Maximum temperature (°C)  \
# 0   2021-01-01    5019.64                      15.6                      29.9
# 1   2021-01-02    4964.35                      18.4                      29.0
# 2   2021-01-03    4503.31                      17.0                      26.2
# 3   2021-01-04    4764.18                      16.0                      18.6
# 4   2021-01-05    4800.64                      15.9                      19.1
# ..         ...        ...                       ...                       ...
# 237 2021-08-27    6769.89                       4.6                      13.6
# 238 2021-08-28    5716.32                       5.3                      17.8
# 239 2021-08-29    6227.89                       9.1                      16.2
# 240 2021-08-30    6072.91                       6.4                      17.6
# 241 2021-08-31    5779.56                      11.0                      20.1
#
#      Rainfall (mm)  Evaporation (mm)  Sunshine (hours)  \
# 0              0.0               2.8               9.3
# 1              0.0               9.4               1.3
# 2             12.6               4.8               7.1
# 3              2.6               3.8               0.0
# 4             11.2               1.0               0.0
# ..             ...               ...               ...
# 237            0.0               1.2               3.8
# 238            0.0               1.6               9.6
# 239            0.6               6.4               4.3
# 240            4.0               1.4               7.4
# 241            0.0               5.8               3.6
#
#     Direction of maximum wind gust   Speed of maximum wind gust (km/h)  \
# 0                               NNE                               31.0
# 1                               NNW                               30.0
# 2                               WSW                               33.0
# 3                               SSE                               41.0
# 4                               SSE                               35.0
# ..                              ...                                ...
# 237                             SSW                               15.0
# 238                               N                               39.0
# 239                             NNE                               33.0
# 240                             NNW                               50.0
# 241                               N                               61.0
#
#     Time of maximum wind gust  ...  9am wind speed (km/h)  \
# 0                       13:14  ...                      2
# 1                        8:22  ...                     17
# 2                       17:55  ...                      4
# 3                       16:03  ...                     11
# 4                       11:02  ...                     13
# ..                        ...  ...                    ...
# 237                     12:18  ...                   Calm
# 238                     13:14  ...                      7
# 239                      1:50  ...                     13
# 240                     14:04  ...                     15
# 241                     16:29  ...                     17
#
#      9am MSL pressure (hPa)  3pm Temperature (°C) 3pm relative humidity (%)  \
# 0                    1018.8                  28.1                        43
# 1                    1013.3                  28.7                        38
# 2                    1007.7                  23.5                        59
# 3                    1010.0                  18.2                        82
# 4                    1012.5                  18.2                        82
# ..                      ...                   ...                       ...
# 237                  1020.0                  12.8                        65
# 238                  1018.6                  17.4                        31
# 239                  1011.4                  12.8                        84
# 240                  1016.1                  16.8                        45
# 241                     NaN                  19.4                        43
#
#     3pm cloud amount (oktas)  3pm wind direction  3pm wind speed (km/h)  \
# 0                        5.0                   E                     13
# 1                        7.0                  SW                      4
# 2                        4.0                 SSW                      2
# 3                        8.0                 SSW                     17
# 4                        8.0                 SSE                     19
# ..                       ...                 ...                    ...
# 237                      7.0                 SSE                      7
# 238                      3.0                 NNW                     24
# 239                      7.0                   S                      6
# 240                      1.0                 NNW                     28
# 241                      6.0                   N                     30
#
#      3pm MSL pressure (hPa)  max_temp_binned         demand_binned
# 0                    1015.3    (24.9, 32.05]  (4469.326, 5403.995]
# 1                    1008.5    (24.9, 32.05]  (4469.326, 5403.995]
# 2                    1005.2    (24.9, 32.05]  (4469.326, 5403.995]
# 3                    1011.0    (17.75, 24.9]  (4469.326, 5403.995]
# 4                    1013.3    (17.75, 24.9]  (4469.326, 5403.995]
# ..                      ...              ...                   ...
# 237                  1017.4  (10.571, 17.75]   (6334.94, 7265.885]
# 238                  1013.5    (17.75, 24.9]   (5403.995, 6334.94]
# 239                  1010.4  (10.571, 17.75]   (5403.995, 6334.94]
# 240                  1013.2  (10.571, 17.75]   (5403.995, 6334.94]
# 241                  1012.2    (17.75, 24.9]   (5403.995, 6334.94]
#
# [242 rows x 24 columns]
# NMI : 0.3240703194716581

# %%
FEATURES=['MAXDEMAND','Maximum temperature (°C)']
df[FEATURES].corr(method='pearson')
# Out:
#                           MAXDEMAND  Maximum temperature (°C)
# MAXDEMAND                  1.000000                 -0.292191
# Maximum temperature (°C)  -0.292191                  1.000000

# %%
plt.scatter(df['Maximum temperature (°C)'], df['MAXDEMAND'],alpha=0.5)
plt.xlabel("Maximum temperature (°C)")
plt.ylabel("Maximum demand")
plt.show()

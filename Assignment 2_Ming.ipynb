# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
weather_df=pd.read_csv("weather_data.csv")

# %%
price_df=pd.read_csv("price_demand_data.csv")

# %%
display(weather_df)
# Out:
#           Date  Minimum temperature (°C)  Maximum temperature (°C)  \
# 0   2021-01-01                      15.6                      29.9
# 1   2021-01-02                      18.4                      29.0
# 2   2021-01-03                      17.0                      26.2
# 3   2021-01-04                      16.0                      18.6
# 4   2021-01-05                      15.9                      19.1
# ..         ...                       ...                       ...
# 238 2021-08-27                       4.6                      13.6
# 239 2021-08-28                       5.3                      17.8
# 240 2021-08-29                       9.1                      16.2
# 241 2021-08-30                       6.4                      17.6
# 242 2021-08-31                      11.0                      20.1
#
#      Rainfall (mm)  Evaporation (mm)  Sunshine (hours)  \
# 0              0.0               2.8               9.3
# 1              0.0               9.4               1.3
# 2             12.6               4.8               7.1
# 3              2.6               3.8               0.0
# 4             11.2               1.0               0.0
# ..             ...               ...               ...
# 238            0.0               1.2               3.8
# 239            0.0               1.6               9.6
# 240            0.6               6.4               4.3
# 241            4.0               1.4               7.4
# 242            0.0               5.8               3.6
#
#     Direction of maximum wind gust   Speed of maximum wind gust (km/h)  \
# 0                               NNE                               31.0
# 1                               NNW                               30.0
# 2                               WSW                               33.0
# 3                               SSE                               41.0
# 4                               SSE                               35.0
# ..                              ...                                ...
# 238                             SSW                               15.0
# 239                               N                               39.0
# 240                             NNE                               33.0
# 241                             NNW                               50.0
# 242                               N                               61.0
#
#     Time of maximum wind gust  9am Temperature (°C)  ...  \
# 0                       13:14                  19.2  ...
# 1                        8:22                  23.3  ...
# 2                       17:55                  18.3  ...
# 3                       16:03                  16.2  ...
# 4                       11:02                  17.2  ...
# ..                        ...                   ...  ...
# 238                     12:18                   7.7  ...
# 239                     13:14                   9.1  ...
# 240                      1:50                  10.6  ...
# 241                     14:04                  11.1  ...
# 242                     16:29                  13.5  ...
#
#      9am cloud amount (oktas)  9am wind direction 9am wind speed (km/h)  \
# 0                           6                   N                     2
# 1                           7                 NNW                    17
# 2                           8                 WSW                     4
# 3                           8                 SSE                    11
# 4                           8                 SSE                    13
# ..                        ...                 ...                   ...
# 238                         7                                      Calm
# 239                         1                   N                     7
# 240                         7                   N                    13
# 241                         7                   N                    15
# 242                         7                   N                    17
#
#     9am MSL pressure (hPa)  3pm Temperature (°C)  3pm relative humidity (%)  \
# 0                   1018.8                  28.1                         43
# 1                   1013.3                  28.7                         38
# 2                   1007.7                  23.5                         59
# 3                   1010.0                  18.2                         82
# 4                   1012.5                  18.2                         82
# ..                     ...                   ...                        ...
# 238                 1020.0                  12.8                         65
# 239                 1018.6                  17.4                         31
# 240                 1011.4                  12.8                         84
# 241                 1016.1                  16.8                         45
# 242                    NaN                  19.4                         43
#
#      3pm cloud amount (oktas)  3pm wind direction 3pm wind speed (km/h)  \
# 0                         5.0                   E                    13
# 1                         7.0                  SW                     4
# 2                         4.0                 SSW                     2
# 3                         8.0                 SSW                    17
# 4                         8.0                 SSE                    19
# ..                        ...                 ...                   ...
# 238                       7.0                 SSE                     7
# 239                       3.0                 NNW                    24
# 240                       7.0                   S                     6
# 241                       1.0                 NNW                    28
# 242                       6.0                   N                    30
#
#     3pm MSL pressure (hPa)
# 0                   1015.3
# 1                   1008.5
# 2                   1005.2
# 3                   1011.0
# 4                   1013.3
# ..                     ...
# 238                 1017.4
# 239                 1013.5
# 240                 1010.4
# 241                 1013.2
# 242                 1012.2
#
# [243 rows x 21 columns]

# %%
weather_df['Date'] = pd.to_datetime(weather_df['Date'], format='%d/%m/%Y')

# %%
weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Date                               243 non-null    datetime64[ns]
#  1   Minimum temperature (°C)           242 non-null    float64
#  2   Maximum temperature (°C)           242 non-null    float64
#  3   Rainfall (mm)                      241 non-null    float64
#  4   Evaporation (mm)                   243 non-null    float64
#  5   Sunshine (hours)                   243 non-null    float64
#  6   Direction of maximum wind gust     240 non-null    object
#  7   Speed of maximum wind gust (km/h)  240 non-null    float64
#  8   Time of maximum wind gust          240 non-null    object
#  9   9am Temperature (°C)               242 non-null    float64
#  10  9am relative humidity (%)          242 non-null    float64
#  11  9am cloud amount (oktas)           243 non-null    int64
#  12  9am wind direction                 242 non-null    object
#  13  9am wind speed (km/h)              242 non-null    object
#  14  9am MSL pressure (hPa)             241 non-null    float64
#  15  3pm Temperature (°C)               243 non-null    float64
#  16  3pm relative humidity (%)          243 non-null    int64
#  17  3pm cloud amount (oktas)           242 non-null    float64
#  18  3pm wind direction                 243 non-null    object
#  19  3pm wind speed (km/h)              243 non-null    object
#  20  3pm MSL pressure (hPa)             242 non-null    float64
# dtypes: datetime64[ns](1), float64(12), int64(2), object(6)
# memory usage: 40.0+ KB

# %%
display(price_df)
# Out:
#       REGION    SETTLEMENTDATE  TOTALDEMAND PRICECATEGORY
# 0       VIC1    1/01/2021 0:30      4179.21           LOW
# 1       VIC1    1/01/2021 1:00      4047.76           LOW
# 2       VIC1    1/01/2021 1:30      3934.70           LOW
# 3       VIC1    1/01/2021 2:00      3766.45           LOW
# 4       VIC1    1/01/2021 2:30      3590.37           LOW
# ...      ...               ...          ...           ...
# 11659   VIC1  31/08/2021 22:00      4861.91        MEDIUM
# 11660   VIC1  31/08/2021 22:30      4748.74        MEDIUM
# 11661   VIC1  31/08/2021 23:00      4620.09        MEDIUM
# 11662   VIC1  31/08/2021 23:30      4834.00        MEDIUM
# 11663   VIC1    1/09/2021 0:00      4811.27        MEDIUM
#
# [11664 rows x 4 columns]

# %%
# data cleanning - split the SETTLEMENTDATE to Date and TIME
price_df[['Date','TIME']]=price_df['SETTLEMENTDATE'].str.split(' ', expand=True)

# %%
price_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11664 entries, 0 to 11663
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   REGION          11664 non-null  object
#  1   SETTLEMENTDATE  11664 non-null  object
#  2   TOTALDEMAND     11664 non-null  float64
#  3   PRICECATEGORY   11664 non-null  object
#  4   Date            11664 non-null  object
#  5   TIME            11664 non-null  object
# dtypes: float64(1), object(5)
# memory usage: 546.9+ KB

# %%
price_df['Date'] = pd.to_datetime(price_df['Date'], format='%d/%m/%Y')

# %%
price_df.head()
# Out:
#   REGION  SETTLEMENTDATE  TOTALDEMAND PRICECATEGORY       Date  TIME
# 0   VIC1  1/01/2021 0:30      4179.21           LOW 2021-01-01  0:30
# 1   VIC1  1/01/2021 1:00      4047.76           LOW 2021-01-01  1:00
# 2   VIC1  1/01/2021 1:30      3934.70           LOW 2021-01-01  1:30
# 3   VIC1  1/01/2021 2:00      3766.45           LOW 2021-01-01  2:00
# 4   VIC1  1/01/2021 2:30      3590.37           LOW 2021-01-01  2:30

# %%
price_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11664 entries, 0 to 11663
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   REGION          11664 non-null  object
#  1   SETTLEMENTDATE  11664 non-null  object
#  2   TOTALDEMAND     11664 non-null  float64
#  3   PRICECATEGORY   11664 non-null  object
#  4   Date            11664 non-null  datetime64[ns]
#  5   TIME            11664 non-null  object
# dtypes: datetime64[ns](1), float64(1), object(4)
# memory usage: 546.9+ KB

# %%
# sum of the daily energy usage
new_price_df=price_df.groupby(['Date']).sum().reset_index()
new_price_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         244 non-null    datetime64[ns]
#  1   TOTALDEMAND  244 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 3.9 KB

# %%
display(new_price_df)
# Out:
#           Date  TOTALDEMAND
# 0   2021-01-01    185853.37
# 1   2021-01-02    197990.13
# 2   2021-01-03    188742.96
# 3   2021-01-04    199281.07
# 4   2021-01-05    207680.91
# ..         ...          ...
# 239 2021-08-28    209104.93
# 240 2021-08-29    224449.35
# 241 2021-08-30    232158.40
# 242 2021-08-31    226540.29
# 243 2021-09-01      4811.27
#
# [244 rows x 2 columns]

# %%
new_price_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         244 non-null    datetime64[ns]
#  1   TOTALDEMAND  244 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 3.9 KB

# %%
#merge and combine the data sets
df=pd.merge(new_price_df,weather_df,how="inner", on="Date")

# %%
display(df)
# Out:
#           Date  TOTALDEMAND  Minimum temperature (°C)  \
# 0   2021-01-01    185853.37                      15.6
# 1   2021-01-02    197990.13                      18.4
# 2   2021-01-03    188742.96                      17.0
# 3   2021-01-04    199281.07                      16.0
# 4   2021-01-05    207680.91                      15.9
# ..         ...          ...                       ...
# 238 2021-08-27    268490.26                       4.6
# 239 2021-08-28    209104.93                       5.3
# 240 2021-08-29    224449.35                       9.1
# 241 2021-08-30    232158.40                       6.4
# 242 2021-08-31    226540.29                      11.0
#
#      Maximum temperature (°C)  Rainfall (mm)  Evaporation (mm)  \
# 0                        29.9            0.0               2.8
# 1                        29.0            0.0               9.4
# 2                        26.2           12.6               4.8
# 3                        18.6            2.6               3.8
# 4                        19.1           11.2               1.0
# ..                        ...            ...               ...
# 238                      13.6            0.0               1.2
# 239                      17.8            0.0               1.6
# 240                      16.2            0.6               6.4
# 241                      17.6            4.0               1.4
# 242                      20.1            0.0               5.8
#
#      Sunshine (hours) Direction of maximum wind gust   \
# 0                 9.3                             NNE
# 1                 1.3                             NNW
# 2                 7.1                             WSW
# 3                 0.0                             SSE
# 4                 0.0                             SSE
# ..                ...                             ...
# 238               3.8                             SSW
# 239               9.6                               N
# 240               4.3                             NNE
# 241               7.4                             NNW
# 242               3.6                               N
#
#      Speed of maximum wind gust (km/h) Time of maximum wind gust  ...  \
# 0                                 31.0                     13:14  ...
# 1                                 30.0                      8:22  ...
# 2                                 33.0                     17:55  ...
# 3                                 41.0                     16:03  ...
# 4                                 35.0                     11:02  ...
# ..                                 ...                       ...  ...
# 238                               15.0                     12:18  ...
# 239                               39.0                     13:14  ...
# 240                               33.0                      1:50  ...
# 241                               50.0                     14:04  ...
# 242                               61.0                     16:29  ...
#
#      9am cloud amount (oktas)  9am wind direction  9am wind speed (km/h)  \
# 0                           6                   N                      2
# 1                           7                 NNW                     17
# 2                           8                 WSW                      4
# 3                           8                 SSE                     11
# 4                           8                 SSE                     13
# ..                        ...                 ...                    ...
# 238                         7                                       Calm
# 239                         1                   N                      7
# 240                         7                   N                     13
# 241                         7                   N                     15
# 242                         7                   N                     17
#
#     9am MSL pressure (hPa) 3pm Temperature (°C)  3pm relative humidity (%)  \
# 0                   1018.8                 28.1                         43
# 1                   1013.3                 28.7                         38
# 2                   1007.7                 23.5                         59
# 3                   1010.0                 18.2                         82
# 4                   1012.5                 18.2                         82
# ..                     ...                  ...                        ...
# 238                 1020.0                 12.8                         65
# 239                 1018.6                 17.4                         31
# 240                 1011.4                 12.8                         84
# 241                 1016.1                 16.8                         45
# 242                    NaN                 19.4                         43
#
#      3pm cloud amount (oktas)  3pm wind direction  3pm wind speed (km/h)  \
# 0                         5.0                   E                     13
# 1                         7.0                  SW                      4
# 2                         4.0                 SSW                      2
# 3                         8.0                 SSW                     17
# 4                         8.0                 SSE                     19
# ..                        ...                 ...                    ...
# 238                       7.0                 SSE                      7
# 239                       3.0                 NNW                     24
# 240                       7.0                   S                      6
# 241                       1.0                 NNW                     28
# 242                       6.0                   N                     30
#
#     3pm MSL pressure (hPa)
# 0                   1015.3
# 1                   1008.5
# 2                   1005.2
# 3                   1011.0
# 4                   1013.3
# ..                     ...
# 238                 1017.4
# 239                 1013.5
# 240                 1010.4
# 241                 1013.2
# 242                 1012.2
#
# [243 rows x 22 columns]

# %%
df
# Out:
#           Date  TOTALDEMAND  Minimum temperature (°C)  \
# 0   2021-01-01    185853.37                      15.6
# 1   2021-01-02    197990.13                      18.4
# 2   2021-01-03    188742.96                      17.0
# 3   2021-01-04    199281.07                      16.0
# 4   2021-01-05    207680.91                      15.9
# ..         ...          ...                       ...
# 238 2021-08-27    268490.26                       4.6
# 239 2021-08-28    209104.93                       5.3
# 240 2021-08-29    224449.35                       9.1
# 241 2021-08-30    232158.40                       6.4
# 242 2021-08-31    226540.29                      11.0
#
#      Maximum temperature (°C)  Rainfall (mm)  Evaporation (mm)  \
# 0                        29.9            0.0               2.8
# 1                        29.0            0.0               9.4
# 2                        26.2           12.6               4.8
# 3                        18.6            2.6               3.8
# 4                        19.1           11.2               1.0
# ..                        ...            ...               ...
# 238                      13.6            0.0               1.2
# 239                      17.8            0.0               1.6
# 240                      16.2            0.6               6.4
# 241                      17.6            4.0               1.4
# 242                      20.1            0.0               5.8
#
#      Sunshine (hours) Direction of maximum wind gust   \
# 0                 9.3                             NNE
# 1                 1.3                             NNW
# 2                 7.1                             WSW
# 3                 0.0                             SSE
# 4                 0.0                             SSE
# ..                ...                             ...
# 238               3.8                             SSW
# 239               9.6                               N
# 240               4.3                             NNE
# 241               7.4                             NNW
# 242               3.6                               N
#
#      Speed of maximum wind gust (km/h) Time of maximum wind gust  ...  \
# 0                                 31.0                     13:14  ...
# 1                                 30.0                      8:22  ...
# 2                                 33.0                     17:55  ...
# 3                                 41.0                     16:03  ...
# 4                                 35.0                     11:02  ...
# ..                                 ...                       ...  ...
# 238                               15.0                     12:18  ...
# 239                               39.0                     13:14  ...
# 240                               33.0                      1:50  ...
# 241                               50.0                     14:04  ...
# 242                               61.0                     16:29  ...
#
#      9am cloud amount (oktas)  9am wind direction  9am wind speed (km/h)  \
# 0                           6                   N                      2
# 1                           7                 NNW                     17
# 2                           8                 WSW                      4
# 3                           8                 SSE                     11
# 4                           8                 SSE                     13
# ..                        ...                 ...                    ...
# 238                         7                                       Calm
# 239                         1                   N                      7
# 240                         7                   N                     13
# 241                         7                   N                     15
# 242                         7                   N                     17
#
#     9am MSL pressure (hPa) 3pm Temperature (°C)  3pm relative humidity (%)  \
# 0                   1018.8                 28.1                         43
# 1                   1013.3                 28.7                         38
# 2                   1007.7                 23.5                         59
# 3                   1010.0                 18.2                         82
# 4                   1012.5                 18.2                         82
# ..                     ...                  ...                        ...
# 238                 1020.0                 12.8                         65
# 239                 1018.6                 17.4                         31
# 240                 1011.4                 12.8                         84
# 241                 1016.1                 16.8                         45
# 242                    NaN                 19.4                         43
#
#      3pm cloud amount (oktas)  3pm wind direction  3pm wind speed (km/h)  \
# 0                         5.0                   E                     13
# 1                         7.0                  SW                      4
# 2                         4.0                 SSW                      2
# 3                         8.0                 SSW                     17
# 4                         8.0                 SSE                     19
# ..                        ...                 ...                    ...
# 238                       7.0                 SSE                      7
# 239                       3.0                 NNW                     24
# 240                       7.0                   S                      6
# 241                       1.0                 NNW                     28
# 242                       6.0                   N                     30
#
#     3pm MSL pressure (hPa)
# 0                   1015.3
# 1                   1008.5
# 2                   1005.2
# 3                   1011.0
# 4                   1013.3
# ..                     ...
# 238                 1017.4
# 239                 1013.5
# 240                 1010.4
# 241                 1013.2
# 242                 1012.2
#
# [243 rows x 22 columns]

# %%
plt.scatter(df['Maximum temperature (°C)'], df['TOTALDEMAND'])
plt.show()
print("Pearson r is",df['Maximum temperature (°C)'].corr(df['TOTALDEMAND']))
# Out:
# Pearson r is -0.3622123104908116

# %%
# delete columns contains not a number valune
df=df.dropna(subset=['TOTALDEMAND','Minimum temperature (°C)'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 242 entries, 0 to 242
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Date                               242 non-null    datetime64[ns]
#  1   TOTALDEMAND                        242 non-null    float64
#  2   Minimum temperature (°C)           242 non-null    float64
#  3   Maximum temperature (°C)           242 non-null    float64
#  4   Rainfall (mm)                      241 non-null    float64
#  5   Evaporation (mm)                   242 non-null    float64
#  6   Sunshine (hours)                   242 non-null    float64
#  7   Direction of maximum wind gust     240 non-null    object
#  8   Speed of maximum wind gust (km/h)  240 non-null    float64
#  9   Time of maximum wind gust          240 non-null    object
#  10  9am Temperature (°C)               242 non-null    float64
#  11  9am relative humidity (%)          242 non-null    float64
#  12  9am cloud amount (oktas)           242 non-null    int64
#  13  9am wind direction                 242 non-null    object
#  14  9am wind speed (km/h)              242 non-null    object
#  15  9am MSL pressure (hPa)             241 non-null    float64
#  16  3pm Temperature (°C)               242 non-null    float64
#  17  3pm relative humidity (%)          242 non-null    int64
#  18  3pm cloud amount (oktas)           241 non-null    float64
#  19  3pm wind direction                 242 non-null    object
#  20  3pm wind speed (km/h)              242 non-null    object
#  21  3pm MSL pressure (hPa)             241 non-null    float64
#  22  max_temp_binned                    242 non-null    category
#  23  demand_binned                      242 non-null    category
# dtypes: category(2), datetime64[ns](1), float64(13), int64(2), object(6)
# memory usage: 44.2+ KB

# %%
from sklearn.metrics.cluster import normalized_mutual_info_score
df['max_temp_binned']=pd.cut(df['Maximum temperature (°C)'], bins=4)
df['demand_binned']=pd.cut(df['TOTALDEMAND'], bins=4)
display(df)
nmi=normalized_mutual_info_score(df['demand_binned'],df['max_temp_binned'], average_method='min')
print("NMI : "+ str(nmi))
# Out:
#           Date  TOTALDEMAND  Minimum temperature (°C)  \
# 0   2021-01-01    185853.37                      15.6
# 1   2021-01-02    197990.13                      18.4
# 2   2021-01-03    188742.96                      17.0
# 3   2021-01-04    199281.07                      16.0
# 4   2021-01-05    207680.91                      15.9
# ..         ...          ...                       ...
# 238 2021-08-27    268490.26                       4.6
# 239 2021-08-28    209104.93                       5.3
# 240 2021-08-29    224449.35                       9.1
# 241 2021-08-30    232158.40                       6.4
# 242 2021-08-31    226540.29                      11.0
#
#      Maximum temperature (°C)  Rainfall (mm)  Evaporation (mm)  \
# 0                        29.9            0.0               2.8
# 1                        29.0            0.0               9.4
# 2                        26.2           12.6               4.8
# 3                        18.6            2.6               3.8
# 4                        19.1           11.2               1.0
# ..                        ...            ...               ...
# 238                      13.6            0.0               1.2
# 239                      17.8            0.0               1.6
# 240                      16.2            0.6               6.4
# 241                      17.6            4.0               1.4
# 242                      20.1            0.0               5.8
#
#      Sunshine (hours) Direction of maximum wind gust   \
# 0                 9.3                             NNE
# 1                 1.3                             NNW
# 2                 7.1                             WSW
# 3                 0.0                             SSE
# 4                 0.0                             SSE
# ..                ...                             ...
# 238               3.8                             SSW
# 239               9.6                               N
# 240               4.3                             NNE
# 241               7.4                             NNW
# 242               3.6                               N
#
#      Speed of maximum wind gust (km/h) Time of maximum wind gust  ...  \
# 0                                 31.0                     13:14  ...
# 1                                 30.0                      8:22  ...
# 2                                 33.0                     17:55  ...
# 3                                 41.0                     16:03  ...
# 4                                 35.0                     11:02  ...
# ..                                 ...                       ...  ...
# 238                               15.0                     12:18  ...
# 239                               39.0                     13:14  ...
# 240                               33.0                      1:50  ...
# 241                               50.0                     14:04  ...
# 242                               61.0                     16:29  ...
#
#      9am wind speed (km/h)  9am MSL pressure (hPa)  3pm Temperature (°C)  \
# 0                        2                  1018.8                  28.1
# 1                       17                  1013.3                  28.7
# 2                        4                  1007.7                  23.5
# 3                       11                  1010.0                  18.2
# 4                       13                  1012.5                  18.2
# ..                     ...                     ...                   ...
# 238                   Calm                  1020.0                  12.8
# 239                      7                  1018.6                  17.4
# 240                     13                  1011.4                  12.8
# 241                     15                  1016.1                  16.8
# 242                     17                     NaN                  19.4
#
#     3pm relative humidity (%) 3pm cloud amount (oktas)  3pm wind direction  \
# 0                          43                      5.0                   E
# 1                          38                      7.0                  SW
# 2                          59                      4.0                 SSW
# 3                          82                      8.0                 SSW
# 4                          82                      8.0                 SSE
# ..                        ...                      ...                 ...
# 238                        65                      7.0                 SSE
# 239                        31                      3.0                 NNW
# 240                        84                      7.0                   S
# 241                        45                      1.0                 NNW
# 242                        43                      6.0                   N
#
#      3pm wind speed (km/h)  3pm MSL pressure (hPa)  max_temp_binned  \
# 0                       13                  1015.3    (24.9, 32.05]
# 1                        4                  1008.5    (24.9, 32.05]
# 2                        2                  1005.2    (24.9, 32.05]
# 3                       17                  1011.0    (17.75, 24.9]
# 4                       19                  1013.3    (17.75, 24.9]
# ..                     ...                     ...              ...
# 238                      7                  1017.4  (10.571, 17.75]
# 239                     24                  1013.5    (17.75, 24.9]
# 240                      6                  1010.4  (10.571, 17.75]
# 241                     28                  1013.2  (10.571, 17.75]
# 242                     30                  1012.2    (17.75, 24.9]
#
#                 demand_binned
# 0    (178727.118, 208912.773]
# 1    (178727.118, 208912.773]
# 2    (178727.118, 208912.773]
# 3    (178727.118, 208912.773]
# 4    (178727.118, 208912.773]
# ..                        ...
# 238  (238978.165, 269043.558]
# 239  (208912.773, 238978.165]
# 240  (208912.773, 238978.165]
# 241  (208912.773, 238978.165]
# 242  (208912.773, 238978.165]
#
# [242 rows x 24 columns]
# NMI : 0.27904116339854296
